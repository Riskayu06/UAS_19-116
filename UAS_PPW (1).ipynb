# %% [markdown]
# # Nama : Riska Ayu Ramadhani

# %% [markdown]
# # NIM  : 190411100116

# %% [markdown]
# # No. Whatsapp : 087817428067

# %% [markdown]
# Crawling adalah teknik pengumpulan data yang digunakan untuk mengindeks informasi pada halaman menggunakan URL (Uniform Resource Locator) dengan menyertakan API (Application Programming Interface) untuk melakukan penambangan dataset yang lebih besar.

# %% [markdown]
# # Crawling Data

# %% [markdown]
# # Install dan import scrapy

# %% [markdown]
# Melakukan Scrapy
#
# Scrapy merupakan library python yang digunakan untuk melakukan scraping/ crawling data

# %%
# !pip install scrapy
# Out:
# Requirement already satisfied: scrapy in c:\users\asus\appdata\local\programs\python\python38-32\lib\site-packages (2.6.1)
# Requirement already satisfied: cryptography>=2.0 in c:\users\asus\appdata\local\programs\python\python38-32\lib\site-packages (from scrapy) (36.0.2)
# Requirement already satisfied: Twisted>=17.9.0 in c:\users\asus\appdata\local\programs\python\python38-32\lib\site-packages (from scrapy) (22.2.0)
# Requirement already satisfied: protego>=0.1.15 in c:\users\asus\appdata\local\programs\python\python38-32\lib\site-packages (from scrapy) (0.2.1)
# Requirement already satisfied: queuelib>=1.4.2 in c:\users\asus\appdata\local\programs\python\python38-32\lib\site-packages (from scrapy) (1.6.2)
# Requirement already satisfied: lxml>=3.5.0 in c:\users\asus\appdata\local\programs\python\python38-32\lib\site-packages (from scrapy) (4.8.0)
# Requirement already satisfied: w3lib>=1.17.0 in c:\users\asus\appdata\local\programs\python\python38-32\lib\site-packages (from scrapy) (1.22.0)
# Requirement already satisfied: cssselect>=0.9.1 in c:\users\asus\appdata\local\programs\python\python38-32\lib\site-packages (from scrapy) (1.1.0)
# WARNING: Ignoring invalid distribution -ip (c:\users\asus\appdata\local\programs\python\python38-32\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\asus\appdata\local\programs\python\python38-32\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\asus\appdata\local\programs\python\python38-32\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\asus\appdata\local\programs\python\python38-32\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\asus\appdata\local\programs\python\python38-32\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\asus\appdata\local\programs\python\python38-32\lib\site-packages)
# Requirement already satisfied: zope.interface>=4.1.3 in c:\users\asus\appdata\local\programs\python\python38-32\lib\site-packages (from scrapy) (5.4.0)
# Requirement already satisfied: tldextract in c:\users\asus\appdata\local\programs\python\python38-32\lib\site-packages (from scrapy) (3.2.0)
# Requirement already satisfied: itemloaders>=1.0.1 in c:\users\asus\appdata\local\programs\python\python38-32\lib\site-packages (from scrapy) (1.0.4)
# Requirement already satisfied: itemadapter>=0.1.0 in c:\users\asus\appdata\local\programs\python\python38-32\lib\site-packages (from scrapy) (0.4.0)
# Requirement already satisfied: PyDispatcher>=2.0.5 in c:\users\asus\appdata\local\programs\python\python38-32\lib\site-packages (from scrapy) (2.0.5)
# Requirement already satisfied: pyOpenSSL>=16.2.0 in c:\users\asus\appdata\local\programs\python\python38-32\lib\site-packages (from scrapy) (22.0.0)
# Requirement already satisfied: service-identity>=16.0.0 in c:\users\asus\appdata\local\programs\python\python38-32\lib\site-packages (from scrapy) (21.1.0)
# Requirement already satisfied: parsel>=1.5.0 in c:\users\asus\appdata\local\programs\python\python38-32\lib\site-packages (from scrapy) (1.6.0)
# Requirement already satisfied: setuptools in c:\users\asus\appdata\local\programs\python\python38-32\lib\site-packages (from scrapy) (47.1.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\asus\appdata\local\programs\python\python38-32\lib\site-packages (from cryptography>=2.0->scrapy) (1.15.0)
# Requirement already satisfied: jmespath>=0.9.5 in c:\users\asus\appdata\local\programs\python\python38-32\lib\site-packages (from itemloaders>=1.0.1->scrapy) (1.0.0)
# Requirement already satisfied: six>=1.6.0 in c:\users\asus\appdata\roaming\python\python38\site-packages (from parsel>=1.5.0->scrapy) (1.15.0)
# Requirement already satisfied: pyasn1 in c:\users\asus\appdata\local\programs\python\python38-32\lib\site-packages (from service-identity>=16.0.0->scrapy) (0.4.8)
# Requirement already satisfied: pyasn1-modules in c:\users\asus\appdata\local\programs\python\python38-32\lib\site-packages (from service-identity>=16.0.0->scrapy) (0.2.8)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\asus\appdata\local\programs\python\python38-32\lib\site-packages (from service-identity>=16.0.0->scrapy) (21.4.0)
# Requirement already satisfied: hyperlink>=17.1.1 in c:\users\asus\appdata\local\programs\python\python38-32\lib\site-packages (from Twisted>=17.9.0->scrapy) (21.0.0)
# Requirement already satisfied: constantly>=15.1 in c:\users\asus\appdata\local\programs\python\python38-32\lib\site-packages (from Twisted>=17.9.0->scrapy) (15.1.0)
# Requirement already satisfied: Automat>=0.8.0 in c:\users\asus\appdata\local\programs\python\python38-32\lib\site-packages (from Twisted>=17.9.0->scrapy) (20.2.0)
# Requirement already satisfied: incremental>=21.3.0 in c:\users\asus\appdata\local\programs\python\python38-32\lib\site-packages (from Twisted>=17.9.0->scrapy) (21.3.0)
# Requirement already satisfied: typing-extensions>=3.6.5 in c:\users\asus\appdata\local\programs\python\python38-32\lib\site-packages (from Twisted>=17.9.0->scrapy) (4.1.1)
# Requirement already satisfied: twisted-iocpsupport<2,>=1.0.2 in c:\users\asus\appdata\local\programs\python\python38-32\lib\site-packages (from Twisted>=17.9.0->scrapy) (1.0.2)
# Requirement already satisfied: idna in c:\users\asus\appdata\local\programs\python\python38-32\lib\site-packages (from tldextract->scrapy) (3.3)
# Requirement already satisfied: filelock>=3.0.8 in c:\users\asus\appdata\local\programs\python\python38-32\lib\site-packages (from tldextract->scrapy) (3.6.0)
# Requirement already satisfied: requests>=2.1.0 in c:\users\asus\appdata\local\programs\python\python38-32\lib\site-packages (from tldextract->scrapy) (2.27.1)
# Requirement already satisfied: requests-file>=1.4 in c:\users\asus\appdata\local\programs\python\python38-32\lib\site-packages (from tldextract->scrapy) (1.5.1)
# Requirement already satisfied: pycparser in c:\users\asus\appdata\local\programs\python\python38-32\lib\site-packages (from cffi>=1.12->cryptography>=2.0->scrapy) (2.21)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\asus\appdata\local\programs\python\python38-32\lib\site-packages (from requests>=2.1.0->tldextract->scrapy) (1.26.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asus\appdata\local\programs\python\python38-32\lib\site-packages (from requests>=2.1.0->tldextract->scrapy) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\asus\appdata\local\programs\python\python38-32\lib\site-packages (from requests>=2.1.0->tldextract->scrapy) (2.0.12)

# %%
import scrapy
from scrapy.crawler import CrawlerProcess

# %% [markdown]
# # Scraping Web

# %%
class QuotesSpider(scrapy.Spider):
    name = "quotes"
    start_urls = []
    def _init_(self):
        df=pd.read_csv('crawlingweb.csv')
        for page in range(1,10):
            self.start_urls.append(url+str(page))
    def parse(self, response):
        for detail in response.css('a.gray.button::attr(href)'): 
            yield response.follow(detail.get(), callback = self.parse_detail)

    def parse_detail(self, response):
        for data in response.css('#content_journal > ul > li'):
            yield{
                'Judul': data.css('div:nth-child(2) > a::text').get(),
                'Penulis': data.css('div:nth-child(2) > span::text').get().replace('Penulis : ', ''),
                'Dospem 1': data.css('div:nth-child(3) > span::text').get().replace('Dosen Pembimbing I : ', ''),
                'Dospem 2': data.css('div:nth-child(4) > span::text').get().replace('Dosen Pembimbing II :', ''),
                'Abstraksi': data.css('div:nth-child(2) > p::text').get().replace('\n\n|\n','').replace('ABSTRAK', ''),
                'Abstraction': data.css('div:nth-child(4) > p::text').get().replace('\n\n|\n','').replace('ABSTRACT', ''),
                'Link Download': data.css('div:nth-child(5) > a:nth-child(1)::attr(href)').get().replace('.pdf-0.jpg', '.pdf'),
            }

# %% [markdown]
# # Melakukan Import Module

# %% [markdown]
# Terdapat beberapa library yang harus diimport terlebih dahulu.
# - Numpy: NumPy (Numerical Python) adalah library Python yang fokus pada scientific computing dan memiliki kemampuan untuk membentuk objek N-dimensional array, yang mirip dengan list pada Python. Keunggulan NumPy array dibandingkan dengan list pada Python adalah konsumsi memory yang lebih kecil serta runtime yang lebih cepat.
#
# - Pandas (Python for Data Analysis) adalah library Python yang fokus untuk proses analisis data seperti manipulasi data, persiapan data, dan pembersihan data. Pandas menyediakan struktur data dan fungsi high-level untuk membuat data lebih terstruktur, lebih cepat, mudah. Dalam pandas terdapat dua objek yang sering dibahas, yaitu DataFrame dan Series.
#
# - matplotlib.pyplot adalah kumpulan fungsi yang membuat beberapa perubahan pada gambar. misalnya membuat gambar, membuat area plot dalam gambar, menambah label di plot dan lainnya. Biasanya untuk mempermudah secara umum matplotlib.pyplot disingkat menjadi plt import matplotlib.pyplot as plt
#
# - Matplotlib adalah library Python yang fokus pada visualisasi data yang biasa difungsikan membuat plot grafik. matplotlib tersebut dipanggil dan dilakukan import style.
#
# - Seaborn memiliki banyak fungsi untuk visualisasi data dan lebih mudah digunakan untuk menggunakan library seaborn kita harus install library ini terlebih dahulu dengan menggunakan PIP pip install seaborn Untuk menggunakannya import terlebih dahulu dengan perintah seperti ini import seaborn as sns.

# %%
# data visualisation and manipulation
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns

# %% [markdown]
# Melakukan Konfigurasi
#
# set matplotlib ke inline dan menampilkan grafik di bawah sel yang sesuai.

# %%
#configure
# sets matplotlib to inline and displays graphs below the corressponding cell.
# %matplotlib inline  
style.use('fivethirtyeight')
sns.set(style='whitegrid',color_codes=True)

# %% [markdown]
# # Persiapan Preprocessing

# %% [markdown]
# Preprocessing Data merupakan tahapan dalam melakukan mining data. Data Preprocessing atau praproses data biasanya dilakukan melalui cara eliminasi data yang tidak sesuai.
#
# - Stopwords di nltk adalah kata yang paling umum dalam data. Itu adalah kata-kata yang tidak ingin digunakan untuk menggambarkan topik data dan telah ditentukan sebelumnya juga tidak dapat dihapus.
#
# - Tokenization pada dasarnya mengacu pada pemisahan teks yang lebih besar menjadi baris yang lebih kecil, kata-kata atau bahkan membuat kata-kata untuk bahasa non-Inggris.

# %%
#preprocessing
from nltk.corpus import stopwords  #stopwords
from nltk import word_tokenize,sent_tokenize # tokenizing
from nltk.stem import PorterStemmer,LancasterStemmer  # using the Porter Stemmer and Lancaster Stemmer and others
from nltk.stem.snowball import SnowballStemmer
from nltk.stem import WordNetLemmatizer  # lammatizer from WordNet

# %%
# for named entity recognition (NER)
from nltk import ne_chunk

# %%
# vectorizers for creating the document-term-matrix (DTM)
from sklearn.feature_extraction.text import TfidfVectorizer,CountVectorizer

# %% [markdown]
# Melakukan instalasi nltk. Nltk (toolkit bahasa alami) adalah salah satu library python suite yang berisi program yang digunakan untuk melakukan pemrosesan bahasa statistik.

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\asus\appdata\local\programs\python\python38-32\lib\site-packages (3.7)
# WARNING: Ignoring invalid distribution -ip (c:\users\asus\appdata\local\programs\python\python38-32\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\asus\appdata\local\programs\python\python38-32\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\asus\appdata\local\programs\python\python38-32\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\asus\appdata\local\programs\python\python38-32\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\asus\appdata\local\programs\python\python38-32\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\asus\appdata\local\programs\python\python38-32\lib\site-packages)
# Requirement already satisfied: tqdm in c:\users\asus\appdata\local\programs\python\python38-32\lib\site-packages (from nltk) (4.63.1)
# Requirement already satisfied: joblib in c:\users\asus\appdata\local\programs\python\python38-32\lib\site-packages (from nltk) (1.1.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\asus\appdata\local\programs\python\python38-32\lib\site-packages (from nltk) (2022.3.15)
# Requirement already satisfied: click in c:\users\asus\appdata\local\programs\python\python38-32\lib\site-packages (from nltk) (7.1.2)
# Requirement already satisfied: colorama in c:\users\asus\appdata\roaming\python\python38\site-packages (from tqdm->nltk) (0.4.3)

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
#stop-words
stop_words=set(nltk.corpus.stopwords.words('english'))

# %% [markdown]
# # Menampilkan Dataset

# %% [markdown]
# Disini dilakukan proses untuk menampilkan data yang bernama crawlingweb.csv

# %%
df=pd.read_csv('crawlUAS.csv')

# %%
df.head()
# Out:
#                                                Judul                  Penulis  \
# 0  PENGARUH KEPEMIMPINAN DAN KOMPENSASI TERHADAP ...  Hendri Wahyudi Prayitno
# 1  Pengukuran Website Quality Pada Situs Sistem A...   Muhammad Zakaria Utomo
# 2  PENGARUH PERSEPSI MANFAAT, PERSEPSI KEMUDAHAN,...                    Ahmad
# 3  PENGARUH PENGEMBANGAN KARIR TERHADAP SEMANGAT ...         Danial Aziz M.YD
# 4  PENGARUH FAKTOR-FAKTOR STRES KERJA TERHADAP DI...            Saiful Rahman
#
#                                 Dospem 1                            Dospem 2  \
# 0      Dra. Hj. S Anugrahini Irawati, MM      Helmi Buyung Aulia,S,ST,SE,.MT
# 1            Dr. Ir. Nurita Andriani, MM           Nirma Kurriwati, SP, M.Si
# 2      Bambang Setiyo Pambudi, S.E., MM.                Fathor AS, S.E., MM.
# 3         Dr. Hj. Iriani Ismail, Dra.,MM     Drs. Ec. Mudji Kuswinarno, M.Si
# 4  Dr. Muhammad Alkirom Wildan,S.E.,M.Si  Helmi Buyung Aulia,S.ST.,S.E.,M.MT
#
#                                            Abstraksi  \
# 0  Abstrak\r\nPenelitian ini menggunakan metode k...
# 1  Aplikasi nyata pemanfaatan teknologi informasi...
# 2  Tujuan penelitian ini adalah untuk mengidentif...
# 3  PLN merupakan Badan Usaha Milik Negara yang be...
# 4  \r\n\r\nPenelitian ini bertujuan untuk mengeta...
#
#                                          Abstraction  \
# 0  Abstract\r\nThis research use quantitative met...
# 1  Academic portal system in University of Trunoj...
# 2  The purpose of this research was to identify v...
# 3  PLN is a state-owned enterprise dealy with the...
# 4  \r\n\r\nThis study aimed to determine the effe...
#
#                                        Link Download
# 0  https://pta.trunojoyo.ac.id/uploads/journals/0...
# 1  https://pta.trunojoyo.ac.id/uploads/journals/1...
# 2  https://pta.trunojoyo.ac.id/uploads/journals/0...
# 3  https://pta.trunojoyo.ac.id/uploads/journals/0...
# 4  https://pta.trunojoyo.ac.id/uploads/journals/0...

# %% [markdown]
# Lakukan drop kolom pada judul, waktu dan kategori, karena yang akan diproses datanya disini adalah deskripsi.

# %%
# drop judul,penulis, dospem 1 & 2, Abstraction, dan link download
df.drop(['Judul', 'Penulis', 'Dospem 1', 'Dospem 2','Abstraction', 'Link Download'],axis=1,inplace=True)

# %%
df.head(26)
# Out:
#                                             Abstraksi
# 0   Abstrak\r\nPenelitian ini menggunakan metode k...
# 1   Aplikasi nyata pemanfaatan teknologi informasi...
# 2   Tujuan penelitian ini adalah untuk mengidentif...
# 3   PLN merupakan Badan Usaha Milik Negara yang be...
# 4   \r\n\r\nPenelitian ini bertujuan untuk mengeta...
# 5   Munculnya asumsi bahwa lahirnya budaya mengemi...
# 6   Muhammad Sholeh, Pengaruh Iklan Di Televisi Te...
# 7   Atribut produk memberikan pandangan atau gamba...
# 8   Ulfiyatun Mutohharoh, “Analisis Faktor-faktor ...
# 9   \r\nTujuan penelitian ini adalah untuk mengana...
# 10  Anissa Novianti. 090211100010. Pengaruh Atribu...
# 11  Devi Kurniawati, Pengaruh Earning Per Share, N...
# 12  \r\nTujuan penelitian ini adalah (1) untuk men...
# 13  Tujuan penelitian ini adalah untuk mengetahui ...
# 14  Dwi Suhardianto (2013), “Pengaruh Karakteristi...
# 15  Farid,  Pengaruh  Periklanan Di Media Televisi...
# 16  Abstrak\r\n\r\nPengaruh Kecerdasan Emosional T...
# 17  \r\n\r\nPenelitian ini bertujuan untuk mengeta...
# 18  Produktifitas karyawan sangat dibutuhkan perus...
# 19  Syaiful Anwar, Pengaruh keselamatan dan keseha...
# 20  Tujuan penelitian ini adalah untuk mengetahui ...
# 21  Tujuan dari penelitian ini adalah untuk menget...
# 22  \r\n\r\nKinerja pegawai sangat dibutuhkan dala...
# 23  Abstrak\r\nBerdasarkan hasil observasi masalah...
# 24  Dalam perhitungan biaya rawat inap kebanyakan ...
# 25  Perkembangan dan kemajuan industri, salah satu...

# %% [markdown]
# # Cleaning Data

# %% [markdown]
# Salah satu preprocessing adalah melakukan cleaning data untuk melakukan proses pembersihan data yang tidak diperlukan. Dalam tahap ini, data dibersihkan melalui beberapa proses seperti mengisi nilai yang hilang, menghaluskan noisy data, dan menyelesaikan inkonsistensi yang ditemukan. Data juga bisa dibersihkan dengan dibagi menjadi segmen-segmen yang memiliki ukuran serupa lalu dihaluskan (binning).
#
# Disini telah menggunakan lemmatizer dan juga dapat menggunakan stemmer. Juga kata-kata berhenti telah digunakan bersama dengan kata-kata yang panjangnya lebih pendek dari 3 karakter untuk mengurangi beberapa kata yang menyimpang.

# %%
def clean_text(headline):
  le=WordNetLemmatizer()
  word_tokens=word_tokenize(headline)
  tokens=[le.lemmatize(w) for w in word_tokens if w not in stop_words and len(w)>3]
  cleaned_text=" ".join(tokens)
  return cleaned_text

# %% [markdown]
# # Install dan import NLTK

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\asus\appdata\local\programs\python\python38-32\lib\site-packages (3.7)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\asus\appdata\local\programs\python\python38-32\lib\site-packages (from nltk) (2022.3.15)
# Requirement already satisfied: tqdm in c:\users\asus\appdata\local\programs\python\python38-32\lib\site-packages (from nltk) (4.63.1)
# Requirement already satisfied: click in c:\users\asus\appdata\local\programs\python\python38-32\lib\site-packages (from nltk) (7.1.2)
# Requirement already satisfied: joblib in c:\users\asus\appdata\local\programs\python\python38-32\lib\site-packages (from nltk) (1.1.0)
# Requirement already satisfied: colorama in c:\users\asus\appdata\roaming\python\python38\site-packages (from tqdm->nltk) (0.4.3)
# WARNING: Ignoring invalid distribution -ip (c:\users\asus\appdata\local\programs\python\python38-32\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\asus\appdata\local\programs\python\python38-32\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\asus\appdata\local\programs\python\python38-32\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\asus\appdata\local\programs\python\python38-32\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\asus\appdata\local\programs\python\python38-32\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\asus\appdata\local\programs\python\python38-32\lib\site-packages)

# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
# time taking
df['deskripsi_cleaned_text']=df['Abstraksi'].apply(clean_text)

# %%
df.head(30)
# Out:
#                                             Abstraksi  \
# 0   Abstrak\r\nPenelitian ini menggunakan metode k...
# 1   Aplikasi nyata pemanfaatan teknologi informasi...
# 2   Tujuan penelitian ini adalah untuk mengidentif...
# 3   PLN merupakan Badan Usaha Milik Negara yang be...
# 4   \r\n\r\nPenelitian ini bertujuan untuk mengeta...
# 5   Munculnya asumsi bahwa lahirnya budaya mengemi...
# 6   Muhammad Sholeh, Pengaruh Iklan Di Televisi Te...
# 7   Atribut produk memberikan pandangan atau gamba...
# 8   Ulfiyatun Mutohharoh, “Analisis Faktor-faktor ...
# 9   \r\nTujuan penelitian ini adalah untuk mengana...
# 10  Anissa Novianti. 090211100010. Pengaruh Atribu...
# 11  Devi Kurniawati, Pengaruh Earning Per Share, N...
# 12  \r\nTujuan penelitian ini adalah (1) untuk men...
# 13  Tujuan penelitian ini adalah untuk mengetahui ...
# 14  Dwi Suhardianto (2013), “Pengaruh Karakteristi...
# 15  Farid,  Pengaruh  Periklanan Di Media Televisi...
# 16  Abstrak\r\n\r\nPengaruh Kecerdasan Emosional T...
# 17  \r\n\r\nPenelitian ini bertujuan untuk mengeta...
# 18  Produktifitas karyawan sangat dibutuhkan perus...
# 19  Syaiful Anwar, Pengaruh keselamatan dan keseha...
# 20  Tujuan penelitian ini adalah untuk mengetahui ...
# 21  Tujuan dari penelitian ini adalah untuk menget...
# 22  \r\n\r\nKinerja pegawai sangat dibutuhkan dala...
# 23  Abstrak\r\nBerdasarkan hasil observasi masalah...
# 24  Dalam perhitungan biaya rawat inap kebanyakan ...
# 25  Perkembangan dan kemajuan industri, salah satu...
# 26  Tujuan penelitian ini adalah untuk mengetahui ...
# 27  \r\n\r\n\r\nHendra Irawan, Pengaruh Kepercayaa...
# 28  Abstrak\r\n\r\nDevi Kamalia, Pengaruh Marketin...
# 29  \r\nAchmad sulaiman, Analisis kinerja keuangan...
#
#                                deskripsi_cleaned_text
# 0   Abstrak Penelitian menggunakan metode kuantita...
# 1   Aplikasi nyata pemanfaatan teknologi informasi...
# 2   Tujuan penelitian adalah untuk mengidentifikas...
# 3   merupakan Badan Usaha Milik Negara yang berger...
# 4   Penelitian bertujuan untuk mengetahui pengaruh...
# 5   Munculnya asumsi bahwa lahirnya budaya mengemi...
# 6   Muhammad Sholeh Pengaruh Iklan Televisi Terhad...
# 7   Atribut produk memberikan pandangan atau gamba...
# 8   Ulfiyatun Mutohharoh Analisis Faktor-faktor ya...
# 9   Tujuan penelitian adalah untuk menganalisis at...
# 10  Anissa Novianti 090211100010 Pengaruh Atribut ...
# 11  Devi Kurniawati Pengaruh Earning Share Profit ...
# 12  Tujuan penelitian adalah untuk mengetahui peng...
# 13  Tujuan penelitian adalah untuk mengetahui peng...
# 14  Suhardianto 2013 Pengaruh Karakteristik Indivi...
# 15  Farid Pengaruh Periklanan Media Televisi Terha...
# 16  Abstrak Pengaruh Kecerdasan Emosional Terhadap...
# 17  Penelitian bertujuan untuk mengetahui seberapa...
# 18  Produktifitas karyawan sangat dibutuhkan perus...
# 19  Syaiful Anwar Pengaruh keselamatan kesehatan k...
# 20  Tujuan penelitian adalah untuk mengetahui peng...
# 21  Tujuan dari penelitian adalah untuk mengetahui...
# 22  Kinerja pegawai sangat dibutuhkan dalam menjal...
# 23  Abstrak Berdasarkan hasil observasi masalah pa...
# 24  Dalam perhitungan biaya rawat inap kebanyakan ...
# 25  Perkembangan kemajuan industri salah satunya k...
# 26  Tujuan penelitian adalah untuk mengetahui apak...
# 27  Hendra Irawan Pengaruh Kepercayaan Komitmen Te...
# 28  Abstrak Devi Kamalia Pengaruh Marketing Terhad...
# 29  Achmad sulaiman Analisis kinerja keuangan KP-R...

# %% [markdown]
# Drop kolom yang tidak diproses, yang akan didrop/ hapus adalah deskripsi

# %%
df.drop(['Abstraksi'],axis=1,inplace=True)

# %% [markdown]
# # Data Deskripsi_cleaned_text

# %% [markdown]
# Tampilkan data deskripsi_cleaned_text

# %%
df.head(30)
# Out:
#                                deskripsi_cleaned_text
# 0   Abstrak Penelitian menggunakan metode kuantita...
# 1   Aplikasi nyata pemanfaatan teknologi informasi...
# 2   Tujuan penelitian adalah untuk mengidentifikas...
# 3   merupakan Badan Usaha Milik Negara yang berger...
# 4   Penelitian bertujuan untuk mengetahui pengaruh...
# 5   Munculnya asumsi bahwa lahirnya budaya mengemi...
# 6   Muhammad Sholeh Pengaruh Iklan Televisi Terhad...
# 7   Atribut produk memberikan pandangan atau gamba...
# 8   Ulfiyatun Mutohharoh Analisis Faktor-faktor ya...
# 9   Tujuan penelitian adalah untuk menganalisis at...
# 10  Anissa Novianti 090211100010 Pengaruh Atribut ...
# 11  Devi Kurniawati Pengaruh Earning Share Profit ...
# 12  Tujuan penelitian adalah untuk mengetahui peng...
# 13  Tujuan penelitian adalah untuk mengetahui peng...
# 14  Suhardianto 2013 Pengaruh Karakteristik Indivi...
# 15  Farid Pengaruh Periklanan Media Televisi Terha...
# 16  Abstrak Pengaruh Kecerdasan Emosional Terhadap...
# 17  Penelitian bertujuan untuk mengetahui seberapa...
# 18  Produktifitas karyawan sangat dibutuhkan perus...
# 19  Syaiful Anwar Pengaruh keselamatan kesehatan k...
# 20  Tujuan penelitian adalah untuk mengetahui peng...
# 21  Tujuan dari penelitian adalah untuk mengetahui...
# 22  Kinerja pegawai sangat dibutuhkan dalam menjal...
# 23  Abstrak Berdasarkan hasil observasi masalah pa...
# 24  Dalam perhitungan biaya rawat inap kebanyakan ...
# 25  Perkembangan kemajuan industri salah satunya k...
# 26  Tujuan penelitian adalah untuk mengetahui apak...
# 27  Hendra Irawan Pengaruh Kepercayaan Komitmen Te...
# 28  Abstrak Devi Kamalia Pengaruh Marketing Terhad...
# 29  Achmad sulaiman Analisis kinerja keuangan KP-R...

# %%
df['deskripsi_cleaned_text'][0]
# Out:
# 'Abstrak Penelitian menggunakan metode kuantitatif yang menekankan pada pengujian hipotesis Variabel yang digunakan pada penelitian adalah kepemimpinan kompensasi Penelitian dilaksanakan Kantor Dinas Pendidikan Kabupaten Sampang sampel yang digunakan adalah sebanyak orang yang terdiri dari pegawai negeri sipil Hipotesis pertama menjelaskan bahwa variabel bebas secara bersama–sama mempunyai hubungan yang signifikan secara simultan antara kepemimpinan kompensasi terhadap kinerja pegawai terbukti dengan nilai Fhitung pada tingkat sebesar 11,645 dengan nilai sebesar 0,311 Hipotesis kedua menjelaskan bahwa variabel kompensasi sebagai variabel yang mempunyai pengaruh dominan terbukti dengan nilai hitung 3,072 berarti bahwa terdapat pengaruh positif signifikan secara parsial antara variabel bebas terhadap variabel terikat Kesimpulan penelitian adalah pengujian hipotesis pertama menunjukkan bahwa berdasarkan pengujian statistik secara simultan variabel bebas memiliki pengaruh yang signifikan terhadap variabel terikat Pengujian hipotesis kedua membuktikan bahwa variabel kompensasi merupakan variabel yang berpengaruh dominan terhadap kinerja pada pegawai Dinas Pendidikan Kabupaten Sampang Kata kunci Kepemimpinan Kompensasi Kinerja'

# %% [markdown]
# # MENGEKSTRAKSI FITUR DAN MEMBUAT DOCUMENT-TERM-MATRIX ( DTM )

# %% [markdown]
# Di DTM nilainya adalah nilai TFidf.
#
# Saya juga telah menentukan beberapa parameter dari vectorizer TF-IDF.
#
# Berikut poin penting pada LSA
#
# 1) LSA umumnya diimplementasikan dengan nilai TF-IDF dimana-mana dan bukan dengan Count Vectorizer.
#
# 2) max_features tergantung pada daya komputasi Anda dan juga pada eval. matrik (skor koherensi adalah matrik untuk model topik). Cobalah nilai yang memberikan eval terbaik. matrik dan tidak membatasi kekuatan pemrosesan.
#
# 3) Nilai default untuk min_df &max_df bekerja dengan baik.
#
# 4) Dapat mencoba nilai yang berbeda untuk ngram_range.

# %%
vect =TfidfVectorizer(stop_words=stop_words,max_features=1000)

# %%
vect_text=vect.fit_transform(df['deskripsi_cleaned_text'])

# %% [markdown]
# Melihat kata-kata yang paling sering muncul dan langka di berita utama berdasarkan skor idf. Semakin kecil nilainya; lebih umum adalah kata dalam berita utama.

# %%
print(vect_text.shape)
print(vect_text)
# Out:
# (1019, 1000)
#   (0, 467)	0.022635638327625874
#   (0, 391)	0.02250178030957979
#   (0, 122)	0.024709956136154426
#   (0, 573)	0.047881691746207496
#   (0, 536)	0.0815690546806959
#   (0, 539)	0.049454663453802124
#   (0, 889)	0.06982400165883748
#   (0, 114)	0.033929390887651095
#   (0, 566)	0.030163446648598238
#   (0, 432)	0.0700652185554749
#   (0, 935)	0.12399280391183405
#   (0, 629)	0.03208302044532638
#   (0, 732)	0.035790573500601434
#   (0, 932)	0.05688763841434733
#   (0, 112)	0.06074243442421942
#   (0, 320)	0.07379075638406334
#   (0, 243)	0.08694593454547808
#   (0, 668)	0.07420444737000494
#   (0, 821)	0.05079074567243407
#   (0, 400)	0.14700047616227604
#   (0, 7)	0.09074990080207347
#   (0, 825)	0.06661492114827604
#   (0, 950)	0.045912771911561526
#   (0, 289)	0.06265431808451072
#   (0, 597)	0.10445273238487683
#   :	:
#   (1018, 189)	0.031199481834644865
#   (1018, 56)	0.041946309736188445
#   (1018, 972)	0.012027939310659598
#   (1018, 171)	0.029026739528994892
#   (1018, 467)	0.012924654007991324
#   (1018, 391)	0.012848222827019078
#   (1018, 122)	0.056436249597196106
#   (1018, 114)	0.019373239295380564
#   (1018, 629)	0.01831898587463633
#   (1018, 732)	0.061307850816598626
#   (1018, 668)	0.02824651387427449
#   (1018, 934)	0.07777837955652717
#   (1018, 862)	0.05954772619544569
#   (1018, 827)	0.01473602991454183
#   (1018, 85)	0.014038354479395223
#   (1018, 175)	0.043189133959389586
#   (1018, 933)	0.02874082481377824
#   (1018, 34)	0.03794065395051292
#   (1018, 204)	0.035398457838924896
#   (1018, 621)	0.08787864958281642
#   (1018, 996)	0.046169510587892953
#   (1018, 463)	0.01873754981219321
#   (1018, 574)	0.01671216398771911
#   (1018, 555)	0.013447771749500625
#   (1018, 661)	0.05720487180817709

# %%
idf=vect.idf_

# %%
dd=dict(zip(vect.get_feature_names(), idf))
l=sorted(dd, key=(dd).get)
# print(l)
print(l[0],l[-1])
print(dd['variabel'])
print(dd['kantor'])
# Out:
# penelitian need
# 1.298194652840868
# 4.431050344811837
# c:\users\asus\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# Oleh karena itu, dapat dilihat bahwa berdasarkan nilai idf, 'anak' adalah kata yang paling sering terklihat. Sedangkan 'aliyah' paling jarang terlihat di antara berita lainnya.

# %% [markdown]
# # Tahap Topic Modelling LSA

# %% [markdown]
# Latent Semantic Analysis (LSA)
#
# Latent Semantic Analysis (LSA), adalah salah satu teknik dasar dalam pemodelan topik. Ide intinya adalah mengambil matriks dari apa yang kita miliki - dokumen dan istilah - dan menguraikannya menjadi matriks topik dokumen dan matriks istilah topik yang terpisah.
#
# Pendekatan pertama yang digunakan adalah LSA. LSA pada dasarnya adalah dekomposisi nilai tunggal.
#
# SVD menguraikan DTM asli menjadi tiga matriks S=U.(sigma).(V.T). Di sini matriks U menunjukkan matriks dokumen-topik sementara (V) adalah matriks topik-term.
#
# Setiap baris dari matriks U (matriks istilah dokumen) adalah representasi vektor dari dokumen yang sesuai. Panjang vektor ini adalah jumlah topik yang diinginkan. Representasi vektor untuk suku-suku dalam data kami dapat ditemukan dalam matriks V (matriks istilah-topik).
#
# Jadi, SVD memberi kita vektor untuk setiap dokumen dan istilah dalam data kita. Panjang setiap vektor adalah k. Kami kemudian dapat menggunakan vektor-vektor ini untuk menemukan kata-kata dan dokumen serupa menggunakan metode kesamaan kosinus.
#
# Kita dapat menggunakan fungsi truncatedSVD untuk mengimplementasikan LSA. Parameter n_components adalah jumlah topik yang ingin kita ekstrak. Model tersebut kemudian di fit dan ditransformasikan pada hasil yang diberikan oleh vectorizer.
#
# Terakhir perhatikan bahwa LSA dan LSI (I untuk pengindeksan) adalah sama dan yang terakhir kadang-kadang digunakan dalam konteks pencarian informasi.

# %%
from sklearn.decomposition import TruncatedSVD
lsa_model = TruncatedSVD(n_components=30, algorithm='randomized', n_iter=30, random_state=42)

lsa_top=lsa_model.fit_transform(vect_text)

# %%
print(lsa_top)
print(lsa_top.shape)  # (no_of_doc*no_of_topics)
# Out:
# [[ 0.40229073  0.05549972  0.03121153 ...  0.04631198  0.04367907
#    0.01158949]
#  [ 0.16816737 -0.00672889  0.09201281 ... -0.04985049 -0.03141042
#   -0.05278007]
#  [ 0.18972676 -0.0473179   0.0910802  ... -0.0166461   0.02170044
#    0.03666001]
#  ...
#  [ 0.26804609 -0.197341   -0.09325366 ... -0.0561457   0.02366674
#    0.07551328]
#  [ 0.32953475 -0.27080198 -0.14398106 ...  0.04039432  0.00970687
#   -0.00538253]
#  [ 0.22953822 -0.17968864 -0.08953121 ...  0.10554279 -0.03719869
#   -0.02796514]]
# (1019, 30)

# %%
l=lsa_top[0]
print("Document 0 :")
for i,topic in enumerate(l):
  print("Topic ",i," : ",topic*100)
# Out:
# Document 0 :
# Topic  0  :  40.229073130258335
# Topic  1  :  5.5499720223277675
# Topic  2  :  3.1211532951718617
# Topic  3  :  -2.369895379520254
# Topic  4  :  -18.642808040114783
# Topic  5  :  -6.634079942029872
# Topic  6  :  12.621155679089856
# Topic  7  :  -13.692015383800646
# Topic  8  :  -1.3531617247299534
# Topic  9  :  -13.699701687139312
# Topic  10  :  7.667117497825486
# Topic  11  :  -0.7529514135939898
# Topic  12  :  -5.5622626466129805
# Topic  13  :  3.8776036951238955
# Topic  14  :  7.378823408437847
# Topic  15  :  5.922560007074962
# Topic  16  :  -4.4638867955963955
# Topic  17  :  -26.406002480024178
# Topic  18  :  1.0536362594977564
# Topic  19  :  7.321459571775766
# Topic  20  :  -20.0599706018533
# Topic  21  :  17.38276772186992
# Topic  22  :  -1.2794847976840944
# Topic  23  :  17.981624412983948
# Topic  24  :  11.869272082138307
# Topic  25  :  -3.552660962977302
# Topic  26  :  -1.6318208134946635
# Topic  27  :  4.631198356316799
# Topic  28  :  4.367907305778705
# Topic  29  :  1.158949342121136

# %% [markdown]
# Demikian pula untuk dokumen lain kita bisa melakukan proses tersebut. Namun perhatikan bahwa nilai tidak menambah 1 seperti di LSA itu bukan kemungkinan topik dalam dokumen.

# %%
print(lsa_model.components_.shape) # (no_of_topics*no_of_words)
print(lsa_model.components_)
# Out:
# (30, 1000)
# [[ 0.05154667  0.00835509  0.00626683 ...  0.00563758  0.00432133
#    0.00748422]
#  [ 0.04152337  0.00365113  0.00222593 ... -0.00605957 -0.00827659
#   -0.0153578 ]
#  [-0.01940661 -0.0040024  -0.00168403 ...  0.01488802 -0.0055252
#   -0.01176884]
#  ...
#  [ 0.00291341 -0.0072706   0.00039339 ... -0.01013505  0.00030607
#   -0.00503853]
#  [ 0.00143063 -0.00356532 -0.00370652 ... -0.00129472 -0.04393956
#   -0.00122227]
#  [ 0.00985451  0.00747961 -0.00131466 ... -0.00015355 -0.02757589
#    0.00139728]]

# %% [markdown]
# Pada proses ini mendapatkan daftar kata-kata penting untuk masing-masing dari 10 topik seperti yang ditunjukkan. Untuk proses tahapannya disini ditunjukkan 10 kata untuk setiap topik.

# %%
# most important words for each topic
vocab = vect.get_feature_names()

for i, comp in enumerate(lsa_model.components_):
    vocab_comp = zip(vocab, comp)
    sorted_words = sorted(vocab_comp, key= lambda x:x[1], reverse=True)[:10]
    print("Topic "+str(i)+": ")
    for t in sorted_words:
        print(t[0],end=" ")
    print("\n")
# Out:
# Topic 0:
# kerja karyawan terhadap yang kinerja variabel perusahaan penelitian berpengaruh sebesar
#
# Topic 1:
# kerja karyawan kinerja motivasi kepuasan disiplin lingkungan sebesar kompensasi organisasi
#
# Topic 2:
# keputusan pembelian produk merek konsumen kualitas promosi citra variabel mahasiswa
#
# Topic 3:
# ratio saham return equity harga debt earning share current kerja
#
# Topic 4:
# kerja kepuasan prestasi stres kualitas struktur produktivitas pelayanan perusahaan modal
#
# Topic 5:
# saham stock split harga volume sesudah sebelum perdagangan perbedaan yang
#
# Topic 6:
# kepuasan bank pelayanan pegawai pelanggan kualitas yang loan rasio empati
#
# Topic 7:
# bank rasio keuangan merek kerja kinerja karyawan ratio citra loan
#
# Topic 8:
# karyawan kepuasan kinerja pelayanan komitmen kualitas kompensasi pelanggan harga variabel
#
# Topic 9:
# merek kepuasan citra karyawan kualitas nilai sebesar 05 brand pelayanan
#
# Topic 10:
# merek pegawai kepemimpinan citra mahasiswa gaya organisasi trunojoyo universitas belajar
#
# Topic 11:
# mahasiswa bank prestasi loan karyawan madura belajar trunojoyo universitas saham
#
# Topic 12:
# kepemimpinan gaya komitmen organisasi demokratis karyawan rasio promosi keputusan pembelian
#
# Topic 13:
# bank pegawai loan merek kepemimpinan organisasi kinerja bopo komitmen capital
#
# Topic 14:
# split stock sesudah sebelum volume perdagangan perbedaan ratio loan variabel
#
# Topic 15:
# rasio harga kualitas produk kepemimpinan disiplin keuangan gaya mahasiswa kinerja
#
# Topic 16:
# kepemilikan kebijakan mahasiswa keputusan dividen manajerial prestasi belajar nilai universitas
#
# Topic 17:
# organisasi komitmen kecerdasan struktur konflik rasio modal emosional wanita stres
#
# Topic 18:
# perputaran return value added modal piutang struktur economic iklan persediaan
#
# Topic 19:
# komitmen promosi citra harga kompensasi organisasi disiplin rasio merek bauran
#
# Topic 20:
# perputaran kecerdasan piutang emosional disiplin persediaan stres laba biaya kompetensi
#
# Topic 21:
# kompensasi motivasi organisasi komitmen finansial perputaran piutang score produk pembelian
#
# Topic 22:
# perputaran produktivitas rasio kepemilikan piutang profitabilitas persediaan merek variabel harga
#
# Topic 23:
# pegawai produktivitas komitmen pelatihan kompensasi prestasi organisasi pendidikan finansial perputaran
#
# Topic 24:
# konflik wanita peran kecerdasan kepemimpinan kompensasi keluarga gaya ganda stres
#
# Topic 25:
# score altman kebangkrutan model konsumen springate kompetensi iklan zmijewski motivasi
#
# Topic 26:
# loan bopo return perusahaan added deposit operasional value ukuran produk
#
# Topic 27:
# kecerdasan prestasi perputaran bank kompetensi emosional batik promosi piutang dividen
#
# Topic 28:
# faktor konsumen perilaku prestasi sosial rasio batik laba pengrajin budaya
#
# Topic 29:
# kecerdasan emosional disiplin produktivitas laba kompetensi intelektual spiritual biaya surabaya

# %% [markdown]
# # Prepocessing

# %%
import pandas as pd

df= pd.read_csv("crawlUAS.csv")

df.head(30)
# Out:
#                                                 Judul  \
# 0   PENGARUH KEPEMIMPINAN DAN KOMPENSASI TERHADAP ...
# 1   Pengukuran Website Quality Pada Situs Sistem A...
# 2   PENGARUH PERSEPSI MANFAAT, PERSEPSI KEMUDAHAN,...
# 3   PENGARUH PENGEMBANGAN KARIR TERHADAP SEMANGAT ...
# 4   PENGARUH FAKTOR-FAKTOR STRES KERJA TERHADAP DI...
# 5   Pengaruh Budaya Terhadap Perilaku Pengemis Ana...
# 6   Pengaruh Iklan di televisi terhadap keputusan ...
# 7   Pengaruh Atribut Produk Terhadap Keputusan Pem...
# 8   ANALISIS FAKTOR-FAKTOR YANG MENENTUKAN PREFERE...
# 9   ANALISA KUALITAS PELAYANAN JASA UNTUK MENGUKUR...
# 10  PENGARUH ATRIBUT PRODUK TERHADAP KEPUTUSAN PEM...
# 11  PENGARUH EARNING PER SHARE, NET PROFIT MARGIN,...
# 12  PENGARUH PESAN IKLAN TELEVISI TERHADAP MINAT B...
# 13  PENGARUH BRAND IMAGE TERHADAP KEPUTUSAN PEMBEL...
# 14  PENGARUH KARAKTERISTIK INDIVIDU TERHADAP PREST...
# 15  PENGARUH PERIKLANAN DI MEDIA TELEVISI TERHADAP...
# 16  PENGARUH KECERDASAN EMOSIONAL TERHADAP PRESTAS...
# 17  PENGARUH CITRA MEREK TERHADAP KEPUTUSAN PEMBEL...
# 18  Pengaruh Komunikasi yang Efektif Dalam Organis...
# 19  PENGARUH KESELAMATAN DAN KESEHATAN KERJA \r\nT...
# 20  PENGARUH KEPUASAN KERJA DAN MOTIVASI KERJA TER...
# 21  ANALISIS PENGARUH RASIO PROFITABILITAS DAN DIV...
# 22  PENGARUH KEPEMILIKAN SAHAM BAGI KARYAWAN TERHA...
# 23  pengaruh penempatan kerja terhadap motivasi ke...
# 24  RELEVANSI PENENTUAN TARIF JASA RAWAT INAP DENG...
# 25  Bauran Pemasaran Terhadap Keputusan Pembelian ...
# 26  PENGARUH BAURAN PROMOSI TERHADAP KEPUTUSAN PEM...
# 27  PENGARUH KEPERCAYAAN DAN KOMITMENTERHADAP KUAL...
# 28  PENGARUH MARKETING MIX TERHADAP KEPUTUSAN PEMB...
# 29  analisis kinerja keuangan KP-RI EKA KARSA di t...
#
#                     Penulis                               Dospem 1  \
# 0   Hendri Wahyudi Prayitno      Dra. Hj. S Anugrahini Irawati, MM
# 1    Muhammad Zakaria Utomo            Dr. Ir. Nurita Andriani, MM
# 2                     Ahmad      Bambang Setiyo Pambudi, S.E., MM.
# 3          Danial Aziz M.YD         Dr. Hj. Iriani Ismail, Dra.,MM
# 4             Saiful Rahman  Dr. Muhammad Alkirom Wildan,S.E.,M.Si
# 5        Indah Permata Sari       Dr. Hj. Iriani Ismail., Dra.,M.M
# 6           Muhammad Sholeh         Bambang Setiyo Pambudi, S.E,MM
# 7            Nurus Sholehah           Bambang Setiyo P., S.E,. MM.
# 8      ulfiyatun Mutohharoh              Drs. Mohamad Tambrin, MM.
# 9          Farid Ardyansyah      Dr. H. Pribanus Wantara, Drs., MM
# 10          Anissa Novianti           Dr. Nurita Andriani. Ir., MM
# 11          DEVI KURNIAWATI     R. Gatot Heru Pranjoto, S.E., MM\t
# 12                    sahid               Drs. muhamad tambrin. MM
# 13           FARHIS ANGGARA      Bambang Setiyo Pambudi, S.E., MM.
# 14         DWI SUHARDIANTO         Dr. M. ALKIROM WILDAN, SE.,M.Si
# 15                    Farid                            Muh. Syarif
# 16              IMAM GOZALI         Dr. M. Alkiram Wildan,SE.,M.Si
# 17          ACH. QOMARUDDIN     Dr. H. PRIBANUS WANTARA, Drs., MM.
# 18         Zulsiamsyah Yuri          Dr. Hj. Anugrahini SE., M.si.
# 19            Syaiful Anwar                        Muji Kuswinarno
# 20                    IMRON        Dr. M.Alkirom Wildan,SE.,M.,Si.
# 21           ummi choiriyah       R. Gatot Heru Pranjoto, S.E., MM
# 22    RONAL ILMA YUDA PUTRA        Dr.M. Alkirom Wildan, S.E.,M.Si
# 23            heydi loekito                   RM. Moch. Wispandono
# 24            NURUL HIDAYAT         Dr. Ec. Chairul Anam SE, M.Kes
# 25      Ervan Agus Feryanto               Dr.Ir.Nurita Andriani.MM
# 26   Mohamad Akbar Ramadhan              Dr.Ir. Nurita Andriani.MM
# 27            Hendra Irawan                     Hj. S Anugrahini I
# 28             DEVI KAMALIA             Drs. MOHAMMAD TAMBRIN, MM.
# 29          achmad sulaiman              Dr. Chairul Anam SE, MKes
#
#                               Dospem 2  \
# 0       Helmi Buyung Aulia,S,ST,SE,.MT
# 1            Nirma Kurriwati, SP, M.Si
# 2                 Fathor AS, S.E., MM.
# 3      Drs. Ec. Mudji Kuswinarno, M.Si
# 4   Helmi Buyung Aulia,S.ST.,S.E.,M.MT
# 5                       Faidal,SE., MM
# 6                   Suyono, S.E.,M.S.M
# 7                    Suyono S.E, M.S.M
# 8      Yustina Chrismardani, S.Si, MM.
# 9                Hadi Purnomo, SE., MM
# 10                Hadi Purnomo, SE.,MM
# 11         Prasetyo Nugroho, S.pi., MM
# 12               Hadi Purnomo, SE., MM
# 13                 Fathor AS, SE., MM.
# 14   HELMI BUYUNG AULIA S, ST.,SE.,MMT
# 15                        Hadi Purnomo
# 16    Helmi Buyung Aulia,S.ST,SE.,M.MT
# 17                 FATHOR AS, SE., MM.
# 18                      Faidal SE.,MM.
# 19                      Alkirom Wildan
# 20     Drs.Ec. Mujdi Kuswinarno,M.,Si.
# 21         Prasetyo Nugroho, S.pi., MM
# 22                     Faidal, S.E.,MM
# 23                              Faidal
# 24             Purnamawati, S.E., M.Si
# 25             Nirma Kurriwati SP.M.Si
# 26              Hadi Purnomo, S.E.,M.M
# 27                    Mudji Kuswinarno
# 28    YUSTINA CHRISMARDANI, S.Si., MM.
# 29                  Purnamawati SE,MSi
#
#                                             Abstraksi  \
# 0   Abstrak\r\nPenelitian ini menggunakan metode k...
# 1   Aplikasi nyata pemanfaatan teknologi informasi...
# 2   Tujuan penelitian ini adalah untuk mengidentif...
# 3   PLN merupakan Badan Usaha Milik Negara yang be...
# 4   \r\n\r\nPenelitian ini bertujuan untuk mengeta...
# 5   Munculnya asumsi bahwa lahirnya budaya mengemi...
# 6   Muhammad Sholeh, Pengaruh Iklan Di Televisi Te...
# 7   Atribut produk memberikan pandangan atau gamba...
# 8   Ulfiyatun Mutohharoh, “Analisis Faktor-faktor ...
# 9   \r\nTujuan penelitian ini adalah untuk mengana...
# 10  Anissa Novianti. 090211100010. Pengaruh Atribu...
# 11  Devi Kurniawati, Pengaruh Earning Per Share, N...
# 12  \r\nTujuan penelitian ini adalah (1) untuk men...
# 13  Tujuan penelitian ini adalah untuk mengetahui ...
# 14  Dwi Suhardianto (2013), “Pengaruh Karakteristi...
# 15  Farid,  Pengaruh  Periklanan Di Media Televisi...
# 16  Abstrak\r\n\r\nPengaruh Kecerdasan Emosional T...
# 17  \r\n\r\nPenelitian ini bertujuan untuk mengeta...
# 18  Produktifitas karyawan sangat dibutuhkan perus...
# 19  Syaiful Anwar, Pengaruh keselamatan dan keseha...
# 20  Tujuan penelitian ini adalah untuk mengetahui ...
# 21  Tujuan dari penelitian ini adalah untuk menget...
# 22  \r\n\r\nKinerja pegawai sangat dibutuhkan dala...
# 23  Abstrak\r\nBerdasarkan hasil observasi masalah...
# 24  Dalam perhitungan biaya rawat inap kebanyakan ...
# 25  Perkembangan dan kemajuan industri, salah satu...
# 26  Tujuan penelitian ini adalah untuk mengetahui ...
# 27  \r\n\r\n\r\nHendra Irawan, Pengaruh Kepercayaa...
# 28  Abstrak\r\n\r\nDevi Kamalia, Pengaruh Marketin...
# 29  \r\nAchmad sulaiman, Analisis kinerja keuangan...
#
#                                           Abstraction  \
# 0   Abstract\r\nThis research use quantitative met...
# 1   Academic portal system in University of Trunoj...
# 2   The purpose of this research was to identify v...
# 3   PLN is a state-owned enterprise dealy with the...
# 4   \r\n\r\nThis study aimed to determine the effe...
# 5   The emergence of the assumption that the birth...
# 6   Muhammad Sholeh, The Effects of Television Adv...
# 7   Product attributes provide a clear explanation...
# 8   Ulfiyatun Mutohharoh, “The Factor Analysis on ...
# 9   \r\nThe purpose of this study was to analyze t...
# 10  Anissa Novianti. 090211100010. A Study of the ...
# 11  Devi Kurniawati, The Influence of Earning Per ...
# 12  \r\nThe objectives of this research (1) to kno...
# 13  The purpose of this study was to determine the...
# 14  Dwi Suhardianto (2013), “Influence Of Individu...
# 15  Farid, Television Media Influence Of Advertisi...
# 16  \r\n\r\nImam Gozali, The Effect of Emotional I...
# 17  \r\n\r\nThe purpose of this study is to determ...
# 18  Laborer productivity is really needed by compa...
# 19  Syaiful Anwar, The influence of Health and saf...
# 20  The purpose of this research (1) to know the i...
# 21  The purpose of this study is to  the determine...
# 22  The employee performance is very much needed i...
# 23  Abstract\r\n\r\nJob placement is an urgent mat...
# 24  In the calculation of the cost of inpatient ca...
# 25  The development and progress of industries can...
# 26  The purpose of this study are; (1) to determin...
# 27  \r\n\t\r\n\r\nHendra Irawan, Effect of Trast a...
# 28  Abstract\r\n\r\nDevi Kamalia, Influence Market...
# 29  \r\nAchmad Sulaiman, Analysis of the financial...
#
#                                         Link Download
# 0   https://pta.trunojoyo.ac.id/uploads/journals/0...
# 1   https://pta.trunojoyo.ac.id/uploads/journals/1...
# 2   https://pta.trunojoyo.ac.id/uploads/journals/0...
# 3   https://pta.trunojoyo.ac.id/uploads/journals/0...
# 4   https://pta.trunojoyo.ac.id/uploads/journals/0...
# 5   https://pta.trunojoyo.ac.id/uploads/journals/0...
# 6   https://pta.trunojoyo.ac.id/uploads/journals/0...
# 7   https://pta.trunojoyo.ac.id/uploads/journals/0...
# 8   https://pta.trunojoyo.ac.id/uploads/journals/0...
# 9   https://pta.trunojoyo.ac.id/uploads/journals/1...
# 10  https://pta.trunojoyo.ac.id/uploads/journals/0...
# 11  https://pta.trunojoyo.ac.id/uploads/journals/0...
# 12  https://pta.trunojoyo.ac.id/uploads/journals/0...
# 13  https://pta.trunojoyo.ac.id/uploads/journals/0...
# 14  https://pta.trunojoyo.ac.id/uploads/journals/0...
# 15  https://pta.trunojoyo.ac.id/uploads/journals/0...
# 16  https://pta.trunojoyo.ac.id/uploads/journals/0...
# 17  https://pta.trunojoyo.ac.id/uploads/journals/0...
# 18  https://pta.trunojoyo.ac.id/uploads/journals/0...
# 19  https://pta.trunojoyo.ac.id/uploads/journals/0...
# 20  https://pta.trunojoyo.ac.id/uploads/journals/0...
# 21  https://pta.trunojoyo.ac.id/uploads/journals/0...
# 22  https://pta.trunojoyo.ac.id/uploads/journals/0...
# 23  https://pta.trunojoyo.ac.id/uploads/journals/0...
# 24  https://pta.trunojoyo.ac.id/uploads/journals/0...
# 25  https://pta.trunojoyo.ac.id/uploads/journals/0...
# 26  https://pta.trunojoyo.ac.id/uploads/journals/0...
# 27  https://pta.trunojoyo.ac.id/uploads/journals/0...
# 28  https://pta.trunojoyo.ac.id/uploads/journals/0...
# 29  https://pta.trunojoyo.ac.id/uploads/journals/0...

# %%
import string 
import re #regex library


# import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize 
from nltk.probability import FreqDist

# ------ Tokenizing ---------

def remove_tweet_special(text):
    # remove tab, new line, ans back slice
    text = text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")
    # remove non ASCII (emoticon, chinese word, .etc)
    text = text.encode('ascii', 'replace').decode('ascii')
    # remove mention, link, hashtag
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())
    # remove incomplete URL
    return text.replace("http://", " ").replace("https://", " ")
                
df['Abstraksi'] = df['Abstraksi'].apply(remove_tweet_special)

#remove number
def remove_number(text):
    return  re.sub(r"\d+", "", text)

df['Abstraksi'] = df['Abstraksi'].apply(remove_number)

#remove punctuation
def remove_punctuation(text):
    return text.translate(str.maketrans("","",string.punctuation))

df['Abstraksi'] = df['Abstraksi'].apply(remove_punctuation)

#remove whitespace leading & trailing
def remove_whitespace_LT(text):
    return text.strip()

df['Abstraksi'] = df['Abstraksi'].apply(remove_whitespace_LT)

#remove multiple whitespace into single whitespace
def remove_whitespace_multiple(text):
    return re.sub('\s+',' ',text)

df['Abstraksi'] = df['Abstraksi'].apply(remove_whitespace_multiple)

# remove single char
def remove_singl_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

df['Abstraksi'] = df['Abstraksi'].apply(remove_singl_char)

# NLTK word rokenize 
def word_tokenize_wrapper(text):
    return word_tokenize(text)

df['Abstraksi_tokens'] = df['Abstraksi'].apply(word_tokenize_wrapper)

print('Tokenizing Result : \n') 
print(df['Abstraksi_tokens'].head(20))
print('\n\n\n')
# Out:
# Tokenizing Result :
#
# 0     [Abstrak, Penelitian, ini, menggunakan, metode...
# 1     [Aplikasi, nyata, pemanfaatan, teknologi, info...
# 2     [Tujuan, penelitian, ini, adalah, untuk, mengi...
# 3     [PLN, merupakan, Badan, Usaha, Milik, Negara, ...
# 4     [Penelitian, ini, bertujuan, untuk, mengetahui...
# 5     [Munculnya, asumsi, bahwa, lahirnya, budaya, m...
# 6     [Muhammad, Sholeh, Pengaruh, Iklan, Di, Televi...
# 7     [Atribut, produk, memberikan, pandangan, atau,...
# 8     [Ulfiyatun, Mutohharoh, Analisis, Faktorfaktor...
# 9     [Tujuan, penelitian, ini, adalah, untuk, menga...
# 10    [Anissa, Novianti, Pengaruh, Atribut, Produk, ...
# 11    [Devi, Kurniawati, Pengaruh, Earning, Per, Sha...
# 12    [Tujuan, penelitian, ini, adalah, untuk, menge...
# 13    [Tujuan, penelitian, ini, adalah, untuk, menge...
# 14    [Dwi, Suhardianto, Pengaruh, Karakteristik, In...
# 15    [Farid, Pengaruh, Periklanan, Di, Media, Telev...
# 16    [Abstrak, Pengaruh, Kecerdasan, Emosional, Ter...
# 17    [Penelitian, ini, bertujuan, untuk, mengetahui...
# 18    [Produktifitas, karyawan, sangat, dibutuhkan, ...
# 19    [Syaiful, Anwar, Pengaruh, keselamatan, dan, k...
# Name: Abstraksi_tokens, dtype: object

# %%
df['Abstraksi'] = df['Abstraksi'].str.lower()

print('Case Folding Result:\n')
print(df['Abstraksi'].head(20))
print('\n\n\n')
# Out:
# Case Folding Result:
#
# 0     abstrak penelitian ini menggunakan metode kuan...
# 1     aplikasi nyata pemanfaatan teknologi informasi...
# 2     tujuan penelitian ini adalah untuk mengidentif...
# 3     pln merupakan badan usaha milik negara yang be...
# 4     penelitian ini bertujuan untuk mengetahui peng...
# 5     munculnya asumsi bahwa lahirnya budaya mengemi...
# 6     muhammad sholeh pengaruh iklan di televisi ter...
# 7     atribut produk memberikan pandangan atau gamba...
# 8     ulfiyatun mutohharoh analisis faktorfaktor yan...
# 9     tujuan penelitian ini adalah untuk menganalisi...
# 10    anissa novianti pengaruh atribut produk terhad...
# 11    devi kurniawati pengaruh earning per share net...
# 12    tujuan penelitian ini adalah untuk mengetahui ...
# 13    tujuan penelitian ini adalah untuk mengetahui ...
# 14    dwi suhardianto pengaruh karakteristik individ...
# 15    farid pengaruh periklanan di media televisi te...
# 16    abstrak pengaruh kecerdasan emosional terhadap...
# 17    penelitian ini bertujuan untuk mengetahui sebe...
# 18    produktifitas karyawan sangat dibutuhkan perus...
# 19    syaiful anwar pengaruh keselamatan dan kesehat...
# Name: Abstraksi, dtype: object

# %% [markdown]
# # Menghitung Frekuensi Distribusi Token

# %%
# NLTK calc frequency distribution
def freqDist_wrapper(text):
    return FreqDist(text)

df['Abstraksi_tokens_fdist'] = df['Abstraksi_tokens'].apply(freqDist_wrapper)

print('Frequency Tokens : \n') 
print(df['Abstraksi_tokens_fdist'].head(30).apply(lambda x : x.most_common()))
# Out:
# Frequency Tokens :
#
# 0     [(variabel, 9), (yang, 8), (ini, 7), (bahwa, 5...
# 1     [(dan, 8), (akademik, 8), (portal, 5), (yang, ...
# 2     [(menggunakan, 5), (yang, 4), (BRI, 4), (varia...
# 3     [(yang, 7), (PLN, 5), (kerja, 5), (karir, 4), ...
# 4     [(kerja, 5), (stressor, 5), (yang, 4), (Stress...
# 5     [(yang, 13), (budaya, 8), (pengemis, 6), (yait...
# 6     [(terhadap, 5), (yang, 5), (pesan, 5), (XL, 4)...
# 7     [(produk, 19), (yang, 8), (HONDA, 7), (sepeda,...
# 8     [(yang, 16), (produk, 9), (faktor, 9), (online...
# 9     [(Jembatan, 5), (Suramadu, 5), (dan, 4), (peng...
# 10    [(Kamal, 14), (dan, 10), (Perumahan, 7), (Grah...
# 11    [(dan, 10), (yang, 6), (penelitian, 5), (adala...
# 12    [(pesan, 13), (dan, 6), (beli, 6), (yang, 5), ...
# 13    [(yang, 14), (citra, 10), (image, 8), (penelit...
# 14    [(dan, 15), (yang, 13), (dengan, 6), (prestasi...
# 15    [(yang, 5), (pesan, 5), (Pesan, 4), (Shampo, 3...
# 16    [(kecerdasan, 7), (yang, 5), (dan, 5), (kerja,...
# 17    [(dan, 9), (ini, 5), (merek, 5), (sepeda, 5), ...
# 18    [(komunikasi, 12), (yang, 10), (karyawan, 9), ...
# 19    [(kerja, 10), (dan, 7), (keselamatan, 5), (kes...
# 20    [(kerja, 6), (terhadap, 5), (kinerja, 5), (kar...
# 21    [(penelitian, 8), (dan, 8), (yang, 8), (Return...
# 22    [(yang, 8), (Saham, 8), (Kepemilikan, 7), (dan...
# 23    [(kerja, 17), (yang, 8), (motivasi, 7), (terha...
# 24    [(yang, 12), (biaya, 8), (dengan, 8), (rawat, ...
# 25    [(dan, 8), (yang, 7), (variabel, 7), (ini, 6),...
# 26    [(variabel, 7), (promosi, 7), (dan, 7), (keput...
# 27    [(dan, 8), (PT, 6), (terhadap, 6), (kualitas, ...
# 28    [(dan, 9), (variabel, 8), (yang, 7), (peneliti...
# 29    [(tahun, 21), (dan, 16), (pada, 14), (sebanyak...
# Name: Abstraksi_tokens_fdist, dtype: object

# %% [markdown]
# # filtering (Stopword Removal)

# %%
from nltk.corpus import stopwords

# ----------------------- get stopword from NLTK stopword -------------------------------
# get stopword indonesia
list_stopwords = stopwords.words('indonesian')


# ---------------------------- manualy add stopword  ------------------------------------
# append additional stopword
list_stopwords.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo', 
                       'kalo', 'amp', 'biar', 'bikin', 'bilang', 
                       'gak', 'ga', 'krn', 'nya', 'nih', 'sih', 
                       'si', 'tau', 'tdk', 'tuh', 'utk', 'ya', 
                       'jd', 'jgn', 'sdh', 'aja', 'n', 't', 
                       'nyg', 'hehe', 'pen', 'u', 'nan', 'loh', 'rt',
                       '&amp', 'yah'])

# ----------------------- add stopword from txt file ------------------------------------
# read txt stopword using pandas
txt_stopword = pd.read_csv("crawlUAS.csv", names= ["stopwords"], header = None)

# convert stopword string to list & append additional stopword
list_stopwords.extend(txt_stopword["stopwords"][0].split(' '))

# ---------------------------------------------------------------------------------------

# convert list to dictionary
list_stopwords = set(list_stopwords)


#remove stopword pada list token
def stopwords_removal(words):
    return [word for word in words if word not in list_stopwords]

df['Abstraksi_tokens_WSW'] = df['Abstraksi_tokens'].apply(stopwords_removal) 


print(df['Abstraksi_tokens_WSW'].head(30))
# Out:
# 0     [Abstrak, Penelitian, metode, kuantitatif, men...
# 1     [Aplikasi, nyata, pemanfaatan, teknologi, info...
# 2     [Tujuan, penelitian, mengidentifikasi, variabe...
# 3     [PLN, Badan, Usaha, Milik, Negara, bergerak, b...
# 4     [Penelitian, bertujuan, pengaruh, faktorfaktor...
# 5     [Munculnya, asumsi, lahirnya, budaya, mengemis...
# 6     [Muhammad, Sholeh, Pengaruh, Iklan, Di, Televi...
# 7     [Atribut, produk, pandangan, gambaran, produk,...
# 8     [Ulfiyatun, Mutohharoh, Analisis, Faktorfaktor...
# 9     [Tujuan, penelitian, menganalisis, atribut, ku...
# 10    [Anissa, Novianti, Pengaruh, Atribut, Produk, ...
# 11    [Devi, Kurniawati, Pengaruh, Earning, Per, Sha...
# 12    [Tujuan, penelitian, pengaruh, pesan, iklan, t...
# 13    [Tujuan, penelitian, pengaruh, variabel, brand...
# 14    [Dwi, Suhardianto, Pengaruh, Karakteristik, In...
# 15    [Farid, Pengaruh, Periklanan, Di, Media, Telev...
# 16    [Abstrak, Pengaruh, Kecerdasan, Emosional, Ter...
# 17    [Penelitian, bertujuan, pengaruh, citra, merek...
# 18    [Produktifitas, karyawan, dibutuhkan, perusaha...
# 19    [Syaiful, Anwar, Pengaruh, keselamatan, keseha...
# 20    [Tujuan, penelitian, pengaruh, pengaruh, kepua...
# 21    [Tujuan, penelitian, pengaruh, rasio, profitab...
# 22    [Kinerja, pegawai, dibutuhkan, menjalankan, ak...
# 23    [Abstrak, Berdasarkan, hasil, observasi, penel...
# 24    [Dalam, perhitungan, biaya, rawat, inap, keban...
# 25    [Perkembangan, kemajuan, industri, salah, satu...
# 26    [Tujuan, penelitian, variabel, periklanan, pro...
# 27    [Hendra, Irawan, Pengaruh, Kepercayaan, Dan, K...
# 28    [Abstrak, Devi, Kamalia, Pengaruh, Marketing, ...
# 29    [Achmad, sulaiman, Analisis, kinerja, keuangan...
# Name: Abstraksi_tokens_WSW, dtype: object

# %% [markdown]
# # Normalization

# %%
normalizad_word = pd.read_csv("crawlUAS.csv")

normalizad_word_dict = {}

for index, row in normalizad_word.iterrows():
    if row[0] not in normalizad_word_dict:
        normalizad_word_dict[row[0]] = row[1] 

def normalized_term(document):
    return [normalizad_word_dict[term] if term in normalizad_word_dict else term for term in document]

df['Abstraksi_normalized'] = df['Abstraksi_tokens'].apply(stopwords_removal) 


df['Abstraksi_normalized'].head(20)
# Out:
# 0     [Abstrak, Penelitian, metode, kuantitatif, men...
# 1     [Aplikasi, nyata, pemanfaatan, teknologi, info...
# 2     [Tujuan, penelitian, mengidentifikasi, variabe...
# 3     [PLN, Badan, Usaha, Milik, Negara, bergerak, b...
# 4     [Penelitian, bertujuan, pengaruh, faktorfaktor...
# 5     [Munculnya, asumsi, lahirnya, budaya, mengemis...
# 6     [Muhammad, Sholeh, Pengaruh, Iklan, Di, Televi...
# 7     [Atribut, produk, pandangan, gambaran, produk,...
# 8     [Ulfiyatun, Mutohharoh, Analisis, Faktorfaktor...
# 9     [Tujuan, penelitian, menganalisis, atribut, ku...
# 10    [Anissa, Novianti, Pengaruh, Atribut, Produk, ...
# 11    [Devi, Kurniawati, Pengaruh, Earning, Per, Sha...
# 12    [Tujuan, penelitian, pengaruh, pesan, iklan, t...
# 13    [Tujuan, penelitian, pengaruh, variabel, brand...
# 14    [Dwi, Suhardianto, Pengaruh, Karakteristik, In...
# 15    [Farid, Pengaruh, Periklanan, Di, Media, Telev...
# 16    [Abstrak, Pengaruh, Kecerdasan, Emosional, Ter...
# 17    [Penelitian, bertujuan, pengaruh, citra, merek...
# 18    [Produktifitas, karyawan, dibutuhkan, perusaha...
# 19    [Syaiful, Anwar, Pengaruh, keselamatan, keseha...
# Name: Abstraksi_normalized, dtype: object

# %% [markdown]
# # stemmer

# %%
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter


# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['Abstraksi_normalized']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]

df['Abstraksi_tokens_stemmed'] =df['Abstraksi_normalized'].swifter.apply(get_stemmed_term)
print(df['Abstraksi_tokens_stemmed'])
# Out:
# 9618
# ------------------------
# Abstrak : abstrak
# Penelitian : teliti
# metode : metode
# kuantitatif : kuantitatif
# menekankan : tekan
# pengujian : uji
# hipotesis : hipotesis
# Variabel : variabel
# penelitian : teliti
# kepemimpinanX : kepemimpinanx
# kompensasi : kompensasi
# dilaksanakan : laksana
# Kantor : kantor
# Dinas : dinas
# Pendidikan : didik
# Kabupaten : kabupaten
# Sampang : sampang
# sampel : sampel
# orang : orang
# pegawai : pegawai
# negeri : negeri
# sipil : sipil
# non : non
# PNS : pns
# Hipotesis : hipotesis
# variabel : variabel
# bebas : bebas
# bersamasama : bersamasama
# hubungan : hubung
# signifikan : signifikan
# simultan : simultan
# kepemimpinan : pimpin
# kinerja : kerja
# terbukti : bukti
# nilai : nilai
# Fhitung : fhitung
# tingkat : tingkat
# pengaruh : pengaruh
# dominan : dominan
# hitung : hitung
# positif : positif
# parsial : parsial
# terikat : ikat
# Kesimpulan : simpul
# berdasarkan : dasar
# statistik : statistik
# memiliki : milik
# Pengujian : uji
# membuktikan : bukti
# berpengaruh : pengaruh
# Kata : kata
# kunci : kunci
# Kepemimpinan : pimpin
# Kompensasi : kompensasi
# Kinerja : kerja
# Aplikasi : aplikasi
# nyata : nyata
# pemanfaatan : manfaat
# teknologi : teknologi
# informasi : informasi
# komunikasi : komunikasi
# bidang : bidang
# layanan : layan
# administrasi : administrasi
# akademik : akademik
# perguruan : guru
# salah : salah
# satunya : satu
# sistem : sistem
# portal : portal
# Universitas : universitas
# Trunojoyo : trunojoyo
# Madura : madura
# Implementasi : implementasi
# proses : proses
# penyelenggaraannya : selenggara
# menemui : temu
# kendala : kendala
# teknis : teknis
# bertujuan : tuju
# kepuasan : puas
# pelanggan : langgan
# analisis : analisis
# indeks : indeks
# ditinjau : tinjau
# Webqual : webqual
# fokus : fokus
# perbaikan : baik
# mutu : mutu
# pelayanan : layan
# website : website
# Trunjoyo : trunjoyo
# Importance : importance
# Performance : performance
# Analysis : analysis
# kuantitaif : kuantitaif
# deskriptif : deskriptif
# gambaran : gambar
# deskripsi : deskripsi
# lukisan : lukis
# sistematis : sistematis
# faktual : faktual
# akurat : akurat
# kualitas : kualitas
# jasa : jasa
# online : online
# mahasiswaSampelpenelitianiniadalahmahasiswaangkatan : mahasiswasampelpenelitianiniadalahmahasiswaangkatan
# teknik : teknik
# Stratified : stratified
# Random : random
# Sampling : sampling
# alat : alat
# Indeks : indeks
# Kepuasan : puas
# Pelanggan : langgan
# Tingkat : tingkat
# Kepentingan : penting
# Hasil : hasil
# skor : skor
# IKP : ikp
# masuk : masuk
# kategori : kategori
# puas : puas
# Diagram : diagram
# Kartesius : kartesius
# atribut : atribut
# prioritas : prioritas
# utama : utama
# Situs : situs
# mahasiswa : mahasiswa
# jelasdetail : jelasdetail
# ter : ter
# update : update
# KI : ki
# Informasi : informasi
# disitus : situs
# UTM : utm
# dipercaya : percaya
# Melalui : lalu
# pengguna : guna
# aman : aman
# data : data
# KRS : krs
# KHS : khs
# Transkrip : transkrip
# personal : personal
# sesuai : sesuai
# KIP : kip
# importance : importance
# performance : performance
# webqual : webqual
# Tujuan : tuju
# mengidentifikasi : identifikasi
# variabelvariabel : variabelvariabel
# mempengaruhi : pengaruh
# minat : minat
# ulang : ulang
# nasabah : nasabah
# BRI : bri
# Internet : internet
# Banking : banking
# dimana : mana
# populasi : populasi
# kota : kota
# Bangkalan : bangkal
# diperoleh : oleh
# responden : responden
# diambil : ambil
# purposive : purposive
# sampling : sampling
# Teknik : teknik
# regresi : regresi
# linier : linier
# berganda : ganda
# persepsi : persepsi
# manfaat : manfaat
# kemudahan : mudah
# keamanan : aman
# ketersediaan : sedia
# fitur : fitur
# internet : internet
# banking : banking
# kecuali : kecuali
# Kunci : kunci
# Persepsi : persepsi
# Manfaat : manfaat
# Kemudahan : mudah
# Keamanan : aman
# Ketersediaan : sedia
# Fitur : fitur
# Minat : minat
# Ulang : ulang
# Menggunakan : guna
# PLN : pln
# Badan : badan
# Usaha : usaha
# Milik : milik
# Negara : negara
# bergerak : gerak
# penyediaan : sedia
# listrik : listrik
# nasional : nasional
# mengelola : kelola
# bisnisnya : bisnis
# praktekpaktek : praktekpaktek
# terbaik : baik
# mengoptimalisasikan : optimalisasi
# sumbr : sumbr
# daya : daya
# manusia : manusia
# dimiliki : milik
# Salah : salah
# pengembangan : kembang
# karir : karir
# semangat : semangat
# kerja : kerja
# karyawan : karyawan
# Cabang : cabang
# bersifat : sifat
# Besar : besar
# respondenUji : respondenuji
# kuesioner : kuesioner
# uji : uji
# validitas : validitas
# reliabilitas : reliabilitas
# koefisien : koefisien
# determinasi : determinasi
# prestasi : prestasi
# pengenalan : kenal
# kesetiaan : setia
# orgnisasional : orgnisasional
# mentor : mentor
# sponsor : sponsor
# kesempatan : sempat
# tumbuh : tumbuh
# Dari : dari
# diatas : atas
# kuat : kuat
# cabang : cabang
# bangkalan : bangkal
# Pengembangan : kembang
# kerjaKaryawan : kerjakaryawan
# faktorfaktor : faktorfaktor
# stres : stres
# terhdap : terhdap
# disiplin : disiplin
# dosen : dosen
# Dosen : dosen
# terkumpul : kumpul
# Regresi : regresi
# Linier : linier
# Berganda : ganda
# Dengan : dengan
# bantu : bantu
# software : software
# SPSS : spss
# hasil : hasil
# stressor : stressor
# lingkungan : lingkung
# fisik : fisik
# individu : individu
# kelompok : kelompok
# organisasi : organisasi
# KataKunci : katakunci
# Stressor : stressor
# Lingkungan : lingkung
# Fisik : fisik
# Individu : individu
# Kelompok : kelompok
# Organisasi : organisasi
# Disiplin : disiplin
# Kerja : kerja
# Munculnya : muncul
# asumsi : asumsi
# lahirnya : lahir
# budaya : budaya
# mengemis : emis
# disebabkan : sebab
# anak : anak
# memilih : pilih
# profesi : profesi
# pengemis : emis
# keluarga : keluarga
# Budaya : budaya
# sikap : sikap
# periaku : peria
# Hal : hal
# kebiasaan : biasa
# kehidupan : hidup
# seharihari : seharihari
# Berdasarkan : dasar
# perilaku : perilaku
# Kamal : kamal
# kab : kab
# memprihatinkan : prihatin
# indikator : indikator
# mengukur : ukur
# etnografis : etnografis
# Sosialisasi : sosialisasi
# peran : peran
# menyebabkan : sebab
# berprofesi : profesi
# Modus : modus
# operandi : operandi
# bentuk : bentuk
# praktek : praktek
# jaringan : jaring
# desa : desa
# variable : variable
# indicator : indicator
# behavioral : behavioral
# sociology : sociology
# menerangkan : terang
# tingkah : tingkah
# laku : laku
# akibatnya : akibat
# Sedangkan : sedang
# teory : teory
# exchange : exchange
# of : of
# social : social
# kekecewaan : kecewa
# bersumber : sumber
# adnya : adnya
# faktor : faktor
# dorongan : dorong
# Perilaku : perilaku
# Sosial : sosial
# Muhammad : muhammad
# Sholeh : sholeh
# Pengaruh : pengaruh
# Iklan : iklan
# Di : di
# Televisi : televisi
# Terhadap : hadap
# Keputusan : putus
# Konsumen : konsumen
# Untuk : untuk
# Memakai : pakai
# Kartu : kartu
# Seluler : seluler
# XL : xl
# Kecamatan : camat
# Geger : geger
# dibawah : bawah
# bimbingan : bimbing
# Bambang : bambang
# Setiyo : setiyo
# Pambudi : pambudi
# SE : se
# MM : mm
# Suyono : suyono
# MSM : msm
# iklan : iklan
# keputusan : putus
# konsumen : konsumen
# kartu : kartu
# seluler : seluler
# masyarakat : masyarakat
# kecamatan : camat
# Responden : responden
# isi : isi
# pesan : pesan
# struktur : struktur
# format : format
# sumber : sumber
# Uji : uji
# Keywords : keywords
# Isi : isi
# Pesan : pesan
# Struktur : struktur
# Format : format
# Sumber : sumber
# Atribut : atribut
# produk : produk
# pandangan : pandang
# Dealer : dealer
# Surya : surya
# Agung : agung
# Motor : motor
# dealer : dealer
# resmi : resmi
# HONDA : honda
# penjualan : jual
# sepeda : sepeda
# motor : motor
# memperhatikan : perhati
# mengambil : ambil
# pembelian : beli
# teori : teori
# Kotler : kotler
# Armstrong : armstrong
# gaya : gaya
# desain : desain
# memutuskan : putus
# membeli : beli
# Supra : supra
# menyebarkan : sebar
# studi : studi
# mempunyah : mempunyah
# Produk : produk
# Ulfiyatun : ulfiyatun
# Mutohharoh : mutohharoh
# Analisis : analisis
# Faktorfaktor : faktorfaktor
# Menentukan : tentu
# Preferensi : preferensi
# Belanja : belanja
# Online : online
# Fashion : fashion
# Studi : studi
# mahasiwa : mahasiwa
# Fakultas : fakultas
# Ekonomi : ekonomi
# TRUNOJOYO : trunojoyo
# JOURNAL : journal
# OF : of
# ECONOMICS : economics
# Program : program
# Manajemen : manajemen
# Dibawah : bawah
# Drs : drs
# Mohamad : mohamad
# Tambrin : tambrin
# Yustina : yustina
# Crismardani : crismardani
# SSi : ssi
# global : global
# berbasis : bas
# komputer : komputer
# perlahanlahan : perlahanlahan
# menggeser : geser
# konvensional : konvensional
# praktis : praktis
# modern : modern
# berbelanja : belanja
# Seperti : seperti
# dirilis : rilis
# detikcom : detikcom
# dibeli : beli
# fashion : fashion
# tujuan : tuju
# menganalisis : analis
# menentukan : tentu
# preferensi : preferensi
# belanja : belanja
# dipertimbangkan : timbang
# menetukan : menetukan
# berketergantungan : gantung
# interdependent : interdependent
# Jenis : jenis
# accidental : accidental
# Metode : metode
# statistic : statistic
# konfirmatori : konfirmatori
# didapatkan : dapat
# KMO : kmo
# item : item
# menghasilkan : hasil
# rendah : rendah
# klasifikasi : klasifikasi
# MiserableNilai : miserablenilai
# ukuran : ukur
# kecukuperatan : kecukuperatan
# layak : layak
# Harga : harga
# alternatif : alternatif
# harga : harga
# kepentingan : penting
# Jembatan : jembatan
# Suramadu : suramadu
# enam : enam
# ketidak : tidak
# puasan : puas
# Lampu : lampu
# penerangan : terang
# terpasang : pasang
# menyala : nyala
# malam : malam
# Petugas : tugas
# Jasa : jasa
# Marga : marga
# berpenampilan : tampil
# rapi : rapi
# Kondisi : kondisi
# jalan : jalan
# mulus : mulus
# berlubang : lubang
# tiket : tiket
# teliti : teliti
# uang : uang
# kembalian : kembali
# PT : pt
# jaminan : jamin
# asuransi : asuransi
# kecelakaan : celaka
# patroli : patroli
# sungguhsungguh : sungguhsungguh
# mogokban : mogokban
# bocordll : bocordll
# Anissa : anissa
# Novianti : novianti
# Pembelian : beli
# Minyak : minyak
# Goreng : goreng
# Sania : sania
# Pada : pada
# IbuIbu : ibuibu
# Perumahan : rumah
# Graha : graha
# Permai : permai
# Dr : dr
# Nurita : nurita
# Andriani : andriani
# Ir : ir
# Hadi : had
# Purnomo : purnomo
# merek : merek
# kemasan : kemas
# label : label
# minyak : minyak
# goreng : goreng
# ibuibu : ibuibu
# pendekatan : dekat
# berusaha : usaha
# pengambilan : ambil
# simple : simple
# random : random
# pengumpulan : kumpul
# wawancara : wawancara
# kepustakaan : pustaka
# skala : skala
# likert : likert
# menguji : uji
# instrumen : instrumen
# klasik : klasik
# Namun : namun
# Devi : devi
# Kurniawati : kurniawati
# Earning : earning
# Per : per
# Share : share
# Net : net
# Profit : profit
# Margin : margin
# Debt : debt
# to : to
# Asset : asset
# Ratio : ratio
# Return : return
# On : on
# equity : equity
# Saham : saham
# Perusahaan : usaha
# Otomotif : otomotif
# Komponennya : komponen
# Yang : yang
# Terdaftar : daftar
# BEI : bei
# Periode : periode
# Gatot : gatot
# Heru : heru
# Prajoto : prajoto
# Prasetyo : prasetyo
# Nugroho : nugroho
# Spi : spi
# Equity : equity
# saham : saham
# perusahaan : usaha
# otomotif : otomotif
# komponennya : komponen
# terdaftar : daftar
# periode : periode
# Pendekatan : dekat
# Asumsi : asumsi
# Klasik : klasik
# memakai : pakai
# Square : square
# besarnya : besar
# sisanya : sisa
# dipengaruhi : pengaruh
# diteliti : teliti
# earning : earning
# share : share
# net : net
# profit : profit
# margin : margin
# debt : debt
# asset : asset
# ratio : ratio
# return : return
# on : on
# negatif : negatif
# televisi : televisi
# beli : beli
# jamu : jamu
# tolak : tolak
# angin : angin
# sido : sido
# muncul : muncul
# pasar : pasar
# manyar : manyar
# surabaya : surabaya
# respondenTeknik : respondenteknik
# respondenUntuk : respondenuntuk
# klasikSedangkan : klasiksedangkan
# Surabaya : surabaya
# Kuci : kuci
# brand : brand
# image : image
# citra : citra
# flashdisk : flashdisk
# Toshiba : toshiba
# berlandaskan : landas
# filsafat : filsafat
# positivisme : positivisme
# ditetapkan : tetap
# Sampel : sampel
# adjusted : adjusted
# Brand : brand
# corporate : corporate
# user : user
# product : product
# and : and
# consumer : consumer
# purchasing : purchasing
# decisions : decisions
# Dwi : dwi
# Suhardianto : suhardianto
# Karakteristik : karakteristik
# Prestasi : prestasi
# Karyawan : karyawan
# Persero : persero
# Area : area
# Gresik : gresik
# Bapak : bapak
# Alkirom : alkirom
# Wildan : wildan
# Helmi : helm
# Buyung : buyung
# Aulia : aulia
# Manusia : manusia
# unsur : unsur
# terjalin : jalin
# Setiap : tiap
# didalamnya : dalam
# berbedabeda : berbedabeda
# dasarnya : dasar
# perbedaan : beda
# mengarah : arah
# diduga : duga
# ketahui : tahu
# timbul : timbul
# kebutuhan : butuh
# terkandung : kandung
# dikelola : kelola
# negara : negara
# karakteristik : karakteristik
# tiaptiap : tiaptiap
# diharapkan : harap
# tercapai : capai
# maksimal : maksimal
# eksplanatif : eksplanatif
# mengkaji : kaji
# dihipotesiskan : hipotesis
# Dalam : dalam
# peneliti : teliti
# mempelajari : ajar
# Pengalaman : alam
# Usia : usia
# Kemampuan : mampu
# disimpulkan : simpul
# pendidikan : didik
# Thitung : thitung
# Ttabel : ttabel
# sig : sig
# alpha : alpha
# Ada : ada
# pengalaman : alam
# Tidak : tidak
# usia : usia
# kemampuan : mampu
# Farid : farid
# Periklanan : iklan
# Media : media
# Shampo : shampo
# pantene : pantene
# Masyarakat : masyarakat
# Dungkek : dungkek
# Sumenep : sumenep
# softwere : softwere
# periklanan : iklan
# Pantene : pantene
# vareabel : vareabel
# shampoo : shampoo
# KATA : kata
# KUNCI : kunci
# Kecerdasan : cerdas
# Emosional : emosional
# Pegawai : pegawai
# Burneh : burneh
# Tanah : tanah
# Merah : merah
# Galis : galis
# Dan : dan
# Blega : blega
# memilki : memilki
# kecerdasan : cerdas
# emosional : emosional
# memahami : paham
# hati : hati
# menciptakan : cipta
# suasana : suasana
# nyaman : nyaman
# meningkatkan : tingkat
# peningkatan : tingkat
# kerjanya : kerja
# meneliti : teliti
# intrapersonal : intrapersonal
# interpersonal : interpersonal
# linear : linear
# bantuan : bantu
# kunciKecerdasan : kuncikecerdasan
# Intrapersonal : intrapersonal
# Interpersonal : interpersonal
# honda : honda
# Vario : vario
# keunggulan : unggul
# asosiasi : asosiasi
# kekuatan : kuat
# keunikan : uni
# Citra : citra
# Merek : merek
# Keunggulan : unggul
# Asosiasi : asosiasi
# Kekuatan : kuat
# Keunikan : uni
# Produktifitas : produktifitas
# dibutuhkan : butuh
# mewujudkan : wujud
# visi : visi
# misi : misi
# Produktivitas : produktivitas
# ditingkatkan : tingkat
# anggota : anggota
# terlaksananya : laksana
# optimal : optimal
# Terkait : kait
# produktivitas : produktivitas
# kefektifan : kefektifan
# berkomunikasi : komunikasi
# saluran : salur
# kebawah : bawah
# keatas : atas
# horizontal : horizontal
# meningkatnya : tingkat
# kali : kali
# Data : data
# primer : primer
# penyebaran : sebar
# kuisoner : kuisoner
# Adapun : adapun
# respondennya : responden
# Starfood : starfood
# International : international
# paciran : paciran
# lamongan : lamongan
# clustered : clustered
# analisi : analis
# secaa : secaa
# Paciran : paciran
# Lamongan : lamongan
# Komunikasi : komunikasi
# Syaiful : syaiful
# Anwar : anwar
# keselamatan : selamat
# kesehatan : sehat
# Bagian : bagi
# Produksi : produksi
# Marianal : marianal
# Indo : indo
# Prima : prima
# Pamekasan : pamekasan
# Mudji : mudji
# Kuswinarmo : kuswinarmo
# MSi : msi
# Akirom : akirom
# Latar : latar
# Persaingan : saing
# industri : industri
# menuntut : tuntut
# bertahan : tahan
# berkompetisi : kompetisi
# ditempuh : tempuh
# persaingan : saing
# ketat : ketat
# produksi : produksi
# marinal : marinal
# indo : indo
# prima : prima
# pamekasan : pamekasan
# peroleh : oleh
# persamaan : sama
# XXe : xxe
# samasama : samasama
# Marinal : marinal
# bmt : bmt
# ugt : ugt
# sidogiri : sidogiri
# kabupaten : kabupaten
# motivasi : motivasi
# Porporsional : porporsional
# rasio : rasio
# profitabilitas : profitabilitas
# industry : industry
# makanan : makan
# minuman : minum
# masingmasing : masingmasing
# NPM : npm
# ROA : roa
# Investment : investment
# ROI : roi
# ROE : roe
# EPS : eps
# dividend : dividend
# payout : payout
# DPR : dpr
# Bursa : bursa
# Efek : efek
# Indonesia : indonesia
# aktif : aktif
# square : square
# persial : sial
# Retun : retun
# menjalankan : jalan
# aktifitas : aktifitas
# harapan : harap
# mempengaruhinya : pengaruh
# Kepemilikan : milik
# menejerial : menejerial
# Institusional : institusional
# Kepamilikan : kepamilikan
# CVYUDHISTIRA : cvyudhistira
# CVWEST : cvwest
# MAKMUR : makmur
# Clustered : clustered
# Manajerial : manajerial
# Key : key
# words : words
# observasi : observasi
# tenaga : tenaga
# kependidikan : didik
# ciri : ciri
# suka : suka
# terlambat : lambat
# ramah : ramah
# pulang : pulang
# sub : sub
# penempatan : tempat
# status : status
# perkawinan : kawin
# pengaruhnya : pengaruh
# tabel : tabel
# taraf : taraf
# kesalahan : salah
# persentase : persentase
# moderat : moderat
# Sehingga : sehingga
# total : total
# bahwasannya : bahwasannya
# korelasi : korelasi
# angka : angka
# diteiliti : diteiliti
# independen : independen
# Status : status
# Perkawinan : kawin
# Motivasi : motivasi
# perhitungan : hitung
# biaya : biaya
# rawat : rawat
# inap : inap
# kebanyakan : banyak
# rumah : rumah
# sakit : sakit
# tradisional : tradisional
# Padahal : padahal
# berkaitan : kait
# penentuan : tentu
# pokok : pokok
# jual : jual
# tarif : tarif
# Alternatif : alternatif
# menghitung : hitung
# ActivityBased : activitybased
# Costing : costing
# systemABCSuntuk : systemabcsuntuk
# mengatasi : atas
# distorsi : distorsi
# akuntansi : akuntansi
# system : system
# ABCS : abcs
# kalkulasi : kalkulasi
# menelusuri : telusur
# aktivitas : aktivitas
# keproduk : produk
# dinilai : nilai
# cermat : cermat
# biayabiaya : biayabiaya
# skripsi : skripsi
# jenis : jenis
# deskriftif : deskriftif
# menggambarkan : gambar
# melukiskan : lukis
# fenomena : fenomena
# mendeskripsikan : deskripsi
# ABC : abc
# dibandingkan : banding
# kelas : kelas
# VIP : vip
# pembebanan : beban
# overhead : overhead
# rinci : rinci
# driver : driver
# Cost : cost
# Aktivitas : aktivitas
# menimbulkan : timbul
# Perkembangan : kembang
# kemajuan : maju
# lihat : lihat
# perkembangan : kembang
# dunia : dunia
# usaha : usaha
# pesat : pesat
# Fenomena : fenomena
# sejenis : jenis
# bersaing : saing
# mempertahankan : tahan
# strategi : strategi
# bauran : baur
# pemasaran : pasar
# Bauran : baur
# hargapromosi : hargapromosi
# distribusi : distribusi
# Secara : cara
# khusus : khusus
# membahas : bahas
# toko : toko
# Fely : fely
# Jaya : jaya
# LG : lg
# Kacamatan : kacamatan
# tergantung : gantung
# promosi : promosi
# Kemudian : kemudian
# datadata : datadata
# analisa : analisa
# Promosi : promosi
# Distribusi : distribusi
# Akan : akan
# elektronik : elektronik
# saran : saran
# membuka : buka
# letaknya : letak
# strategis : strategis
# publisitas : publisitas
# manakah : mana
# Objek : objek
# Mini : mini
# market : market
# Alfamart : alfamart
# alfamart : alfamart
# kamal : kamal
# meguji : meguji
# mini : mini
# bauaran : bauaran
# segi : segi
# Hendra : hendra
# Irawan : irawan
# Kepercayaan : percaya
# Komitmen : komitmen
# Kualitas : kualitas
# Hubungan : hubung
# Patner : patner
# Adira : adira
# Dinamika : dinamika
# Multi : multi
# Finance : finance
# Tbk : tbk
# Bimbingan : bimbing
# Dra : dra
# Hj : hj
# Anugrahini : anugrahini
# Ec : ec
# Kuswinanrno : kuswinanrno
# Si : si
# penlitian : penlitian
# kepercayaan : percaya
# komitmen : komitmen
# Baik : baik
# Mengetahui : tahu
# survai : survai
# Tehnik : tehnik
# penarikan : tari
# Quota : quota
# dianalisis : analis
# jalur : jalur
# Path : path
# patner : patner
# dinamika : dinamika
# multi : multi
# finance : finance
# usahanya : usaha
# Kamalia : kamalia
# Marketing : marketing
# Mix : mix
# Sentra : sentra
# Mutira : mutira
# Batik : batik
# marketing : marketing
# mix : mix
# meliputi : liput
# lokasi : lokasi
# penelitiannya : teliti
# Mutiara : mutiara
# batik : batik
# survey : survey
# bebasnya : bebas
# terikatnya : ikat
# probability : probability
# Validitas : validitas
# Realibilitas : realibilitas
# men : men
# guji : guji
# varabel : varabel
# Squere : squere
# Angka : angka
# Adjusted : adjusted
# variasi : variasi
# diluar : luar
# keempat : empat
# Berdasrkan : berdasrkan
# Achmad : achmad
# sulaiman : sulaiman
# keuangan : uang
# KPRI : kpri
# EKA : eka
# KARSA : karsa
# tinjau : tinjau
# aspek : aspek
# perputaran : putar
# piutang : piutang
# kas : kas
# profitabilitasDibawah : profitabilitasdibawah
# Chairul : chairul
# Anam : anam
# Ibu : ibu
# Purnamawati : purnamawati
# bagaiman : bagaiman
# diskriptif : diskriptif
# objek : objek
# BANGKALAN : bangkal
# Langkahlangkah : langkahlangkah
# Menghitung : hitung
# Mnghitung : mnghitung
# Inventesmen : inventesmen
# Menganalisis : analis
# membutuhkan : butuh
# peraturan : atur
# MENTRI : tri
# KOPERASI : koperasi
# UMKM : umkm
# efisien : efisien
# Perputaran : putar
# Piutang : piutang
# Pengumpulan : kumpul
# Profitabilitas : profitabilitas
# Ayu : ayu
# Dini : dini
# Massita : massita
# Efektifitas : efektifitas
# Daya : daya
# Bank : bank
# Mandiri : mandiri
# Irawati : irawati
# Faidal : faidal
# efektifitas : efektifitas
# kuantitas : kuantitas
# SDM : sdm
# kantor : kantor
# bank : bank
# mandiri : mandiri
# signifikansi : signifikansi
# Saran : saran
# ditemukan : temu
# sinifikan : sinifikan
# membenahi : benah
# dimensi : dimensi
# relationship : relationship
# Ikatan : ikat
# Empati : empati
# Timbal : timbal
# Balik : balik
# Tabungan : tabung
# Kas : kas
# versi : versi
# simultas : simultas
# empati : empati
# timbal : timbal
# Maka : maka
# persembahan : sembah
# Taufik : taufik
# Nur : nur
# Hidayat : hidayat
# Nilai : nilai
# Loyalitas : loyalitas
# Nasabah : nasabah
# Rakyat : rakyat
# Skripsi : skripsi
# Pembimbing : bimbing
# Pribanus : pribanus
# Wantara : wantara
# Fathor : fathor
# AS : as
# berjudul : judul
# Proses : proses
# Orang : orang
# Dukungan : dukung
# loyalitas : loyalitas
# Purposive : purposive
# sasaran : sasar
# tabungan : tabung
# berdomisiliwarga : berdomisiliwarga
# berumur : umur
# rumus : rumus
# dikumpulkan : kumpul
# diukur : ukur
# Pengolahan : olah
# perangkat : perangkat
# lunak : lunak
# dukungan : dukung
# determinan : determinan
# Customer : customer
# Value : value
# Awareness : awareness
# Image : image
# Es : es
# Krim : krim
# Walls : walls
# diolah : olah
# datanya : data
# awareness : awareness
# positioning : positioning
# penggunaan : guna
# handphone : handphone
# Nokia : nokia
# Mahasiswa : mahasiswa
# Positioning : positioning
# strategy : strategy
# characteristics : characteristics
# price : price
# quality : quality
# usage : usage
# users : users
# consumers : consumers
# rokok : rokok
# Mild : mild
# Socah : socah
# Menjalani : jalan
# pekerjaan : kerja
# mencampur : campur
# adukkan : aduk
# permasalahan : masalah
# dirumah : rumah
# tangga : tangga
# membawa : bawa
# kedalam : dalam
# sulit : sulit
# penuh : penuh
# Beban : beban
# berat : berat
# berdampak : dampak
# pekerjaannya : kerja
# tugas : tugas
# dilakukannya : laku
# mengikuti : ikut
# pelatihan : latih
# jangka : jangka
# lembur : lembur
# konflik : konflik
# ganda : ganda
# pekerjaankeluarga : pekerjaankeluarga
# keluargapekerjaan : keluargapekerjaan
# perawat : awat
# wanita : wanita
# RS : rs
# Syamrabu : syamrabu
# purpossive : purpossive
# Reliabilitas : reliabilitas
# kinerjanya : kerja
# Konflik : konflik
# Peran : peran
# Ganda : ganda
# Pekerjaankeluarga : pekerjaankeluarga
# KeluargaPekerjaan : keluargapekerjaan
# langkah : langkah
# diperhatikan : perhati
# diterima : terima
# barang : barang
# Swalayan : swalayan
# Kopontren : kopontren
# Sidogiri : sidogiri
# bisnis : bisnis
# eceran : ecer
# pemebelian : beli
# elemenelemen : elemenelemen
# ekuitas : ekuitas
# kesadaran : sadar
# Assocations : assocations
# kesan : kesan
# Perceived : perceived
# Quality : quality
# Loyalty : loyalty
# Blackberry : blackberry
# MaduraTeknik : madurateknik
# MaduraVariabel : maduravariabel
# Martabak : martabak
# Hawaii : hawaii
# Ike : ike
# Miranti : miranti
# Strategi : strategi
# Maan : maan
# Ghodaqo : ghodaqo
# Siddiq : siddiq
# Lestari : lestari
# Jombang : jombang
# Dibimbing : bimbing
# SEMM : semm
# Nirma : nirma
# KurriwatiSPMsi : kurriwatispmsi
# menitikberatkan : menitikberatkan
# Populasi : populasi
# air : air
# mineral : mineral
# purprosive : purprosive
# Maret : maret
# instrument : instrument
# reabilitas : reabilitas
# memakaiuji : memakaiuji
# pengolahan : olah
# Muzanni : muzanni
# Peranan : peran
# tertahadap : tertahadap
# Rentabilitas : rentabilitas
# Koperasi : koperasi
# Berbasis : bas
# Syariah : syariah
# Konvensional : konvensional
# BMT : bmt
# UGT : ugt
# Pembantu : bantu
# Kopergu : kopergu
# Evaliati : evaliati
# Amaniyah : amaniyah
# Lembaga : lembaga
# memperoleh : oleh
# pendapatan : dapat
# pinjaman : pinjam
# pendanaan : dana
# otomatis : otomatis
# Semakin : makin
# modal : modal
# tertanam : tanam
# potensi : potensi
# keuntungan : untung
# Sebaliknya : balik
# Besarnya : besar
# penerapan : terap
# manajemen : manajemen
# rentabilitas : rentabilitas
# lembaga : lembaga
# peranan : peran
# pengelolaan : kelola
# diterapkan : terap
# rasiorasio : rasiorasio
# kriterian : kriterian
# koperasi : koperasi
# pertumbuhan : tumbuh
# cepat : cepat
# ekonomi : ekonomi
# mengalami : alami
# meningkat : tingkat
# penurunan : turun
# KUSNIYAH : kusniyah
# Volume : volume
# Perdagangan : dagang
# Sebelum : belum
# Sesudah : sudah
# Stock : stock
# Split : split
# Go : go
# Public : public
# Kenaikan : naik
# permintaan : minta
# statis : statis
# fluktuatif : fluktuatif
# menghindari : hindar
# munculnya : muncul
# kondisi : kondisi
# stock : stock
# split : split
# likuiditas : likuiditas
# bukti : bukti
# empiris : empiris
# volume : volume
# perdagangan : dagang
# paired : paired
# sample : sample
# variebel : variebel
# memilik : milik
# terbesar : besar
# Yamaha : yamaha
# New : new
# Jupiter : jupiter
# liniear : liniear
# hasilnya : hasil
# aplikasi : aplikasi
# for : for
# windows : windows
# Simultan : simultan
# Parsial : parsial
# Pemasaran : pasar
# Petis : petis
# Ikan : ikan
# Tuna : tuna
# HDiya : hdiya
# Kelurahan : lurah
# Banyuanyar : banyuanyar
# kosumen : kosumen
# Berdasar : dasar
# model : model
# ditribusi : ditribusi
# pengirim : kirim
# komunikator : komunikator
# media : media
# penerima : terima
# komunikan : komunikan
# umpan : umpan
# produktifitas : produktifitas
# Pendidikian : kian
# dinas : dinas
# proporsional : proporsional
# membagikan : bagi
# riset : riset
# perpustakaan : pustaka
# Ftabel : ftabel
# Koefisien : koefisien
# Determinasi : determinasi
# Atau : atau
# dimasukkan : masuk
# varibel : varibel
# langsung : langsung
# kominkator : kominkator
# sigifikan : sigifikan
# upaya : upaya
# Pengirim : kirim
# Komunikator : komunikator
# Penerima : terima
# Komunikan : komunikan
# Umpan : umpan
# penyedap : sedap
# Masako : masako
# populasinya : populasi
# Robatal : robatal
# mengkonsumsi : konsumsi
# Kemasan : kemas
# pelabelan : label
# pelengkap : lengkap
# dependen : dependen
# Selanjutnya : lanjut
# Simpulan : simpul
# kebudayaan : budaya
# sosial : sosial
# pribadi : pribadi
# psikologis : psikologis
# Susu : susu
# Cair : cair
# Indomilk : indomilk
# Tom : tom
# Jerry : jerry
# susu : susu
# cair : cair
# indomilk : indomilk
# swalayan : swalayan
# tom : tom
# jerry : jerry
# Kebudayaan : budaya
# Pribadi : pribadi
# Psikologis : psikologis
# deterjen : deterjen
# Rinso : rinso
# Anti : anti
# Noda : noda
# berdomisili : domisili
# Telang : telang
# konsep : konsep
# AIDA : aida
# helm : helm
# INK : ink
# attention : attention
# interest : interest
# desire : desire
# action : action
# profesionalisme : profesionalisme
# keterampilan : terampil
# aksesibilitas : aksesibilitas
# fleksibilitas : fleksibilitas
# reputasi : reputasi
# kredibilitas : kredibilitas
# service : service
# recovery : recovery
# serviscape : serviscape
# pasien : pasien
# Rumah : rumah
# Sakit : sakit
# Umum : umum
# Terpadu : padu
# servisecape : servisecape
# Pelayanan : layan
# Pasien : pasien
# Bundling : bundling
# Strategy : strategy
# Restoran : restoran
# Quick : quick
# Chicken : chicken
# Raya : raya
# Dukuh : dukuh
# Kupang : kupang
# SurabayaDibimbing : surabayadibimbing
# Chrismardani : chrismardani
# bundling : bundling
# focus : focus
# form : form
# saji : saji
# restoran : restoran
# paketan : paket
# SurabayaMetode : surabayametode
# desember : desember
# lapang : lapang
# mebagikan : mebagikan
# mengunakan : mengunakan
# menunjukan : tunjuk
# Dapat : dapat
# menurunkan : turun
# kisaran : kisar
# menarik : tarik
# investor : investor
# pemecahan : pecah
# test : test
# pengamatan : amat
# penetuan : penetuan
# ratarata : ratarata
# TVA : tva
# Artinya : arti
# pergerakan : gera
# Intention : intention
# this : this
# research : research
# is : is
# know : know
# influence : influence
# location : location
# ofis : ofis
# effort : effort
# XTerhadap : xterhadap
# decision : decision
# also : also
# whichsuch : whichsuch
# having : having
# bigger : bigger
# pPengaruh : ppengaruh
# at : at
# home : home
# Eat : eat
# Depot : depot
# Soto : soto
# Glorious : glorious
# Asih : asih
# This : this
# Research : research
# use : use
# quantitative : quantitative
# method : method
# with : with
# approach : approach
# population : population
# entireall : entireall
# doingconducting : doingconducting
# Method : method
# the : the
# used : used
# hence : hence
# get : get
# responder : responder
# collecting : collecting
# into : into
# library : library
# Result : result
# mention : mention
# tied : tied
# that : that
# While : while
# result : result
# from : from
# prove : prove
# free : free
# consisting : consisting
# by : by
# or : or
# together : together
# Of : of
# can : can
# be : be
# concluded : concluded
# both : both
# which : which
# have : have
# Business : business
# Location : location
# Purchase : purchase
# Decision : decision
# kebangkrutan : bangkrut
# bangkrut : bangkrut
# Altman : altman
# peringatan : ingat
# tandatanda : tandatanda
# Peneliti : teliti
# dijadikan : jadi
# zscore : zscore
# kritis : kritis
# sehat : sehat
# Kebangkrutan : bangkrut
# BangkalanSecara : bangkalansecara
# Habibah : habibah
# Ekuitas : ekuitas
# Notebook : notebook
# Acer : acer
# notebook : notebook
# Ini : ini
# dibuktikan : bukti
# penguasaan : kuasa
# hamper : hamper
# dasar : dasar
# kenyataan : nyata
# Penelitan : penelitan
# penelitan : penelitan
# Hening : hening
# Ary : ary
# Putra : putra
# Facebook : facebook
# Pakaian : pakai
# Bisnis : bisnis
# Pemimbing : pemimbing
# frekuensi : frekuensi
# klik : klik
# vairabel : vairabel
# pakaian : pakai
# rekrutmen : rekrutmen
# Pusat : pusat
# Cipta : cipta
# Sejahtera : sejahtera
# Rekrutmen : rekrutmen
# RekrutmenPengembangan : rekrutmenpengembangan
# Suatu : suatu
# investasi : investasi
# berhubungan : hubung
# risiko : risiko
# Investor : investor
# rasional : rasional
# menginvestasikan : investasi
# dananya : dana
# minimal : minimal
# membagi : bagi
# dividen : dividen
# berturutturut : berturutturut
# membentuk : bentuk
# portofolio : portofolio
# kandidat : kandidat
# cutoffpoint : cutoffpoint
# Portofolio : portofolio
# dibentuk : bentuk
# excess : excess
# returns : returns
# beta : beta
# ERB : erb
# Ci : ci
# Komposisi : komposisi
# proporsi : proporsi
# dana : dana
# Adaro : adaro
# Energy : energy
# Gudang : gudang
# Garam : garam
# HM : hm
# Sampoerna : sampoerna
# Astra : astra
# Otopart : otopart
# Bintang : bintang
# Agro : agro
# Goodyear : goodyear
# Indika : indika
# United : united
# Tractors : tractors
# Pabrik : pabrik
# Kertas : kertas
# Tjiwi : tjiwi
# Kimia : kimia
# Indofood : indofood
# Sukses : sukses
# Makmur : makmur
# tunggal : tunggal
# benarbenar : benarbenar
# aktiva : aktiva
# Model : model
# Tunggal : tunggal
# expected : expected
# self : self
# efficacy : efficacy
# magnitude : magnitude
# generality : generality
# strength : strength
# berprestasi : prestasi
# Dimana : mana
# mawapres : mawapres
# Self : self
# Efficacy : efficacy
# Temuan : temu
# teridiri : teridiri
# Magnitude : magnitude
# Generality : generality
# Strength : strength
# Akademik : akademik
# Relationship : relationship
# kebenaran : benar
# wilayah : wilayah
# barat : barat
# Abtrak : abtrak
# USWATUN : uswatun
# KHASANAH : khasanah
# Etos : etos
# Presatasi : presatasi
# PTPLN : ptpln
# Diatribusi : diatribusi
# Jawa : jawa
# Timur : timur
# Mojokerto : mojokerto
# Kuesioner : kuesioner
# dibagikan : bagi
# etos : etos
# semanagt : semanagt
# rangka : rangka
# meniliti : meniliti
# Pos : pos
# persero : persero
# perubahan : ubah
# kebenarannya : benar
# finansial : finansial
# nonfinansial : nonfinansial
# Credit : credit
# Risk : risk
# NPL : npl
# PD : pd
# BPR : bpr
# Daerah : daerah
# resiko : resiko
# dikatagorikan : dikatagorikan
# ketentuan : tentu
# syarat : syarat
# Non : non
# Performing : performing
# Loan : loan
# Barokah : barokah
# Prambon : prambon
# Accidental : accidental
# kehandalan : kehandalan
# tanggap : tanggap
# Serta : serta
# Bukti : bukti
# Kehandalan : kehandalan
# Tanggap : tanggap
# Jaminan : jamin
# Dharma : dharma
# Abidin : abidin
# SyahKesimpulan : syahkesimpulan
# Terdapat : dapat
# tipe : tipe
# Autoritarian : autoritarian
# LaissezFaire : laissezfaire
# Demokratis : demokratis
# Pangarengan : pangarengan
# anova : anova
# kontribusi : kontribusi
# Tipe : tipe
# Autoritariansecara : autoritariansecara
# pegawaidikantor : pegawaidikantor
# LaissezFairesecara : laissezfairesecara
# lainya : lai
# dikantor : kantor
# Haryono : haryono
# Arifin : arifin
# Honda : honda
# Dealler : dealler
# dianalisa : dianalisa
# Versi : versi
# Aththaariq : aththaariq
# Kompetensi : kompetensi
# DrRM : drrm
# Moch : moch
# WispandonoSEMS : wispandonosems
# WildanSEMSi : wildansemsi
# kompetensi : kompetensi
# pedagogik : pedagogik
# profesional : profesional
# kepribadian : pribadi
# tersertifikasi : sertifikasi
# judgmental : judgmental
# koefisiensi : koefisiensi
# kepribadiandan : kepribadiandan
# Retailing : retailing
# merchandise : merchandise
# atmosfer : atmosfer
# gerai : gerai
# retailimg : retailimg
# Idola : idola
# Mart : mart
# Kwanyar : kwanyar
# rumusan : rumus
# pelaporan : lapor
# meminimalkan : minimal
# cacat : cacat
# CV : cv
# Kapuas : kapuas
# Inti : inti
# Sarana : sarana
# berasal : asal
# periodik : periodik
# terperinci : perinci
# mengurangi : kurang
# Apabila : apabila
# berkurang : kurang
# Risiko : risiko
# inovasi : inovasi
# diterapkannya : terap
# Optik : optik
# Reza : reza
# kualitatif : kualitatif
# fenomenologi : fenomenologi
# dokumen : dokumen
# reduction : reduction
# display : display
# conclusion : conclusion
# drawing : drawing
# verification : verification
# Setelah : telah
# menerapkan : terap
# omzet : omzet
# ditawarkannya : tawar
# pangsa : pangsa
# pasarnya : pasar
# meluas : luas
# daerah : daerah
# Tengah : tengah
# Inovasi : inovasi
# Bersaing : saing
# efektivitas : efektivitas
# Consumer : consumer
# CDM : cdm
# path : path
# analysis : analysis
# keyakinan : yakin
# niat : niat
# Nyata : nyata
# keberhasilan : hasil
# jasaIndah : jasaindah
# Berman : man
# Evans : evans
# Foster : foster
# Indah : indah
# BangkalanNamun : bangkalannamun
# BangakalanVariabel : bangakalanvariabel
# Ali : ali
# Rahbini : rahbini
# Berbelanja : belanja
# Kurriwati : kurriwati
# Keandalan : andal
# celebrity : celebrity
# endorser : endorser
# Iwan : iwan
# Fals : fals
# Top : top
# Coffee : coffee
# Sumur : sumur
# Kembang : kembang
# Pejagan : pejagan
# menngunakan : menngunakan
# aksidental : aksidental
# erangkat : erangkat
# trustworthiness : trustworthiness
# expertise : expertise
# attractiveness : attractiveness
# respect : respect
# similarity : similarity
# minet : minet
# miant : miant
# current : current
# firm : firm
# size : size
# leverage : leverage
# business : business
# risk : risk
# kebijakan : bijak
# deviden : deviden
# manufaktur : manufaktur
# businees : businees
# association : association
# Kiddrock : kiddrock
# distro : distro
# Cranberries : cranberries
# survei : survei
# Desember : desember
# lapangan : lapang
# field : field
# pengolaha : pengolaha
# identifikasi : identifikasi
# kesediaan : sedia
# menerima : terima
# perluasan : luas
# merekomendasikan : rekomendasi
# Cranberriess : cranberriess
# apresisasikan : apresisasikan
# Association : association
# Presepsi : presepsi
# Satiyah : satiyah
# Pelatihan : latih
# Kelautan : laut
# Perikanan : ikan
# DraHjSAnugrahini : drahjsanugrahini
# IrawatiMM : irawatimm
# AuliaSSTSEMMT : auliasstsemmt
# mudah : mudah
# program : program
# instansi : instansi
# efektif : efektif
# pengembnagan : pengembnagan
# menyesuaikan : sesuai
# kebutuhankebutuhan : kebutuhankebutuhan
# pengetahuan : tahu
# tuntutan : tuntut
# mendukung : dukung
# terciptanya : cipta
# kondusif : kondusif
# produktivitasi : produktivitas
# menganalisa : menganalisa
# observasional : observasional
# analitik : analitik
# kuisioner : kuisioner
# probality : probality
# jabatan : jabat
# partisipasi : partisipasi
# seleksi : seleksi
# peserta : serta
# instruktur : instruktur
# Terbukti : bukti
# Faktor : faktor
# thitung : thitung
# Sebesar : besar
# Keberadaan : ada
# didalam : dalam
# memegang : pegang
# pentingPerusahaan : pentingperusahaan
# membangun : bangun
# lingkungannyaDalam : lingkungannyadalam
# menempuh : tempuh
# pemberian : beri
# pencapaian : capai
# Syarifah : syarifah
# Ambami : ambami
# Rato : rato
# Ebu : ebu
# adalahu : adalahu
# ntuk : ntuk
# menilai : nilai
# paramedis : paramedis
# sampelnya : sampel
# ujivaliditasuji : ujivaliditasuji
# asum : asum
# siklasik : siklasik
# penjelasanY : penjelasany
# ujit : ujit
# Dilihat : lihat
# Kesehatan : sehat
# penyakit : sakit
# akibat : akibat
# berjalan : jalan
# Adiluhung : adiluhung
# Saranasegara : saranasegara
# Keselamatan : selamat
# mencoba : coba
# danbudaya : danbudaya
# PERSERO : persero
# APJ : apj
# kantorPLN : kantorpln
# mengindikasikan : indikasi
# berperan : peran
# Jaringan : jaring
# Karena : karena
# acuan : acu
# merancang : rancang
# perencanaan : rencana
# laba : laba
# penginapan : inap
# wisma : wisma
# cost : cost
# dillakukan : dillakukan
# break : break
# event : event
# point : point
# BEP : bep
# safetytingkat : safetytingkat
# batas : batas
# meramalkan : ramal
# dijual : jual
# time : time
# series : series
# least : least
# pustaka : pustaka
# obyek : obyek
# CVP : cvp
# Rp : rp
# Safety : safety
# Proyeksi : proyeksi
# memprediksi : prediksi
# kamar : kamar
# Tahun : tahun
# Analisa : analisa
# Perencanaan : rencana
# Laba : laba
# Laili : laili
# Rahmawati : rahmawati
# Meningkatkan : tingkat
# Cab : cab
# Iriani : iriani
# Ismail : ismail
# DraMM : dramm
# Kuswinarno : kuswinarno
# berkembang : kembang
# koefesien : koefesien
# kenaikan : naik
# Kereta : kereta
# Api : api
# KAI : kai
# bertugas : tugas
# menyelenggarakan : selenggara
# transportasi : transportasi
# kegiatan : giat
# operasionalnya : operasional
# efisiensi : efisiensi
# member : member
# tambahan : tambah
# menunjang : tunjang
# operasional : operasional
# peruasahaan : peruasahaan
# Gerbong : gerbong
# Listrik : listrik
# dll : dll
# pembiayaan : biaya
# mempertimbangkan : timbang
# Tentu : tentu
# disertai : serta
# seimbang : imbang
# pengeluaran : keluar
# memenuhi : penuh
# hutang : hutang
# leasing : leasing
# laporan : lapor
# membandingkan : banding
# present : present
# value : value
# Penentuan : tentu
# dipilih : pilih
# terkecil : kecil
# menguntungkan : untung
# go : go
# public : public
# pembagian : bagi
# perbandingan : banding
# tunai : tunai
# sederhana : sederhana
# berpasangan : pasang
# normalitas : normalitas
# diuji : uji
# normal : normal
# Kebijakan : bijak
# Pembagian : bagi
# signifikansinya : signifikansi
# beda : beda
# perdangan : dang
# Bandung : bandung
# pembenahan : benah
# Alat : alat
# Cash : cash
# Current : current
# Collection : collection
# Periods : periods
# Inventory : inventory
# Turn : turn
# Over : over
# Total : total
# Rasio : rasio
# Modal : modal
# Sendiri : sendiri
# AktivaTMS : aktivatms
# TA : ta
# bobot : bobot
# solvabilitas : solvabilitas
# probabilitas : probabilitas
# Tri : tri
# Aji : aji
# KUALITAS : kualitas
# PELAYANAN : layan
# DAN : dan
# CITRA : citra
# PERUSAHAAN : usaha
# TERHADAP : hadap
# KEPUASAN : puas
# KONSUMEN : konsumen
# Circle : circle
# Taman : taman
# Apsari : apsari
# TambrinMMdan : tambrinmmdan
# circle : circle
# taman : taman
# apsari : apsari
# mengumpulkan : kumpul
# mengevaluasi : evaluasi
# Asizah : asizah
# Perpustakaan : pustaka
# membantu : bantu
# bagus : bagus
# Perguruan : guru
# berupaya : upaya
# reliabiltas : reliabiltas
# universitas : universitas
# trunojoyo : trunojoyo
# madura : madura
# domian : domian
# Sulaihah : sulaihah
# PTTrisakti : pttrisakti
# Muh : muh
# Syarif : syarif
# DrsEcMSi : drsecmsi
# Yudhi : yudhi
# Prasetya : prasetya
# Mada : mada
# keistimewaan : istimewa
# tahan : tahan
# kesesuaian : sesuai
# estetika : estetika
# sensus : sensus
# Pendahuluan : dahulu
# dipersepsikan : persepsi
# Perbandingan : banding
# Capital : capital
# Pricing : pricing
# CAPM : capm
# Arbitrage : arbitrage
# Theory : theory
# APT : apt
# Memprediksi : prediksi
# Komponen : komponen
# memprediksikan : prediksi
# komponen : komponen
# dekriptif : dekriptif
# sekunder : sekunder
# ditolak : tolak
# inflasi : inflasi
# SBI : sbi
# kurs : kurs
# beredar : edar
# MADE : made
# ARDI : ardi
# DHARMAWAN : dharmawan
# Isotonik : isotonik
# Pocari : pocari
# Sweat : sweat
# Minuman : minum
# isotonik : isotonik
# Marketix : marketix
# Harismatullah : harismatullah
# Pendelegasian : delegasi
# Wewenang : wewenang
# Anugerahini : anugerahini
# pendelegasian : delegasi
# wewenang : wewenang
# melaksanakan : laksana
# perangkapan : perangkap
# ketidakjelasan : ketidakjelasan
# lambatnya : lambat
# pelaksanaan : laksana
# pretasi : pretasi
# karyawannya : karyawannya
# pos : pos
# Oli : oli
# Enduro : enduro
# Penurunan : turun
# pencitraan : citra
# buruk : buruk
# banyaknya : banyak
# dipasarkan : pasar
# mengggunakan : mengggunakan
# pembalian : balian
# dilatar : latar
# belakangi : belakang
# ketatnya : ketat
# segmen : segmen
# mobil : mobil
# MPV : mpv
# Suzuki : suzuki
# Ertiga : ertiga
# tinjauan : tinjau
# penyusunan : susun
# Datadata : datadata
# indpenden : indpenden
# Jadi : jadi
# Yogi : yogi
# Grantiyono : grantiyono
# Memilih : pilih
# Mi : mi
# Nurul : nurul
# Huda : huda
# Desa : desa
# Pagar : pagar
# Batu : batu
# Saronggi : saronggi
# SP : sp
# II : ii
# pakai : pakai
# products : products
# place : place
# promotion : promotion
# people : people
# physical : physical
# evidence : evidence
# process : process
# MI : mi
# Pagarbatu : pagarbatu
# wali : wali
# murid : murid
# menetapkan : tetap
# acak : acak
# dipakai : pakai
# kriteria : kriteria
# Jumlah : jumlah
# Telkom : telkom
# Speedy : speedy
# Tempat : tempat
# Aisiyah : aisiyah
# Arifatin : arifatin
# Menghadapi : hadap
# Antar : antar
# Republik : republik
# Mataram : mataram
# Pademawu : pademawu
# Barat : barat
# produknya : produk
# mengoptimalkan : optimal
# mencapai : capai
# mengharuskan : harus
# perusahannya : usah
# matriks : matriks
# BCG : bcg
# relatif : relatif
# Matriks : matriks
# dokumentasi : dokumentasi
# pesaingnya : saing
# Bhinneka : bhinneka
# Karya : karya
# matrik : matrik
# Matrik : matrik
# kuadran : kuadran
# Cow : cow
# Sapi : sapi
# Perah : perah
# Yaitu : yaitu
# dikembangkan : kembang
# mengembangkan : kembang
# diferensiasi : diferensiasi
# simpanan : simpan
# unik : unik
# haji : haji
# qurban : qurban
# kredit : kredit
# Monica : monica
# Maharani : maharani
# Industri : industri
# Klampar : klampar
# Proppo : proppo
# kumpulan : kumpul
# membidik : bidik
# pengrajin : rajin
# manajer : manajer
# dikemukakan : muka
# maksud : maksud
# petani : tani
# analisisa : analisisa
# reduksi : reduksi
# Langkah : langkah
# direduksi : reduksi
# penyajian : saji
# uraian : urai
# singkat : singkat
# kesimpulan : simpul
# rumput : rumput
# laut : laut
# Pekandangan : kandang
# penanganan : tangan
# bibit : bibit
# pasarkan : pasar
# Permodalan : modal
# Bluto : bluto
# pembayaran : bayar
# instansiinstansi : instansiinstansi
# terkait : kait
# menghambat : hambat
# Kurangnya : kurang
# penjemuran : jemur
# pedagang : dagang
# pengumpul : kumpul
# Petani : tani
# Rumput : rumput
# Laut : laut
# Ah : ah
# Faqih : faqih
# Qoriwildani : qoriwildani
# Telekomunikasi : telekomunikasi
# Kota : kota
# Layanan : layan
# speedy : speedy
# menjamin : jamin
# seratus : ratus
# persen : persen
# memuaskan : muas
# pelanggannya : langgan
# berlangganan : langgan
# dianggap : anggap
# berdasar : dasar
# Tele : tele
# Collector : collector
# Kredit : kredit
# Elektronik : elektronik
# psikis : psikis
# beban : beban
# SurabayaJumlah : surabayajumlah
# Nonfisik : nonfisik
# Wilayah : wilayah
# IV : iv
# Pekerjaan : kerja
# padatdi : padatdi
# memakan : makan
# latar : latar
# mencari : cari
# Coefisien : coefisien
# dampak : dampak
# Nilam : nilam
# Mustika : mustika
# Hemastuti : hemastuti
# Operasional : operasional
# Biaya : biaya
# Persepam : sepam
# Menuju : tuju
# Sepakbola : sepakbola
# MKes : mkes
# SPi : spi
# klub : klub
# sepakbola : sepakbola
# interview : interview
# pemantauan : pantau
# pengendalian : kendali
# PMU : pmu
# penyelenggaraan : selenggara
# pertandingan : tanding
# riil : riil
# peluang : peluang
# hiburan : hibur
# olahraga : olahraga
# AJB : ajb
# Bumiputera : bumiputera
# fungsional : fungsional
# disfungsional : disfungsional
# adlah : adlah
# maju : maju
# disebarkan : sebar
# Pertamina : pertamina
# TBBM : tbbm
# Camplong : camplong
# SampangMadura : sampangmadura
# Windows : windows
# Ho : ho
# tertinggi : tinggi
# Rendahnya : rendah
# aktual : aktual
# dikaji : kaji
# dicapai : capai
# tugasnya : tugas
# tanggung : tanggung
# produktif : produktif
# keberadaan : ada
# dirasakan : rasa
# manfaatnya : manfaat
# terwujud : wujud
# pencahayaan : cahaya
# pewarnaan : warna
# kontrol : kontrol
# suara : suara
# musik : musik
# udara : udara
# konservasi : konservasi
# energi : energi
# Adiluhing : adiluhing
# masyarakatnya : masyarakat
# dibidang : bidang
# salon : salon
# kecantikan : cantik
# tampil : tampil
# cantik : cantik
# percaya : percaya
# bermunculan : muncul
# menawarkan : tawar
# perawatan : awat
# ujung : ujung
# rambut : rambut
# kaki : kaki
# sarana : sarana
# kebersihan : bersih
# kelengkapan : lengkap
# alatalat : alatalat
# disediakan : sedia
# Salon : salon
# ketujuh : tujuh
# elemen : elemen
# kuntitatif : kuntitatif
# terstruktur : struktur
# Ketujuh : tujuh
# Samsuki : samsuki
# Iklim : iklim
# BANK : bank
# BUMN : bumn
# calon : calon
# iklim : iklim
# lingkungannya : lingkung
# mendorong : dorong
# pelayan : layan
# nasabahnya : nasabah
# Dilanjutkan : lanjut
# imbalan : imbal
# kehangatan : hangat
# simutan : simutan
# Reny : reny
# Nurhalimah : nurhalimah
# added : added
# sektor : sektor
# farmasi : farmasi
# bursa : bursa
# efek : efek
# Echsan : echsan
# Gani : gani
# berinvestasi : investasi
# Market : market
# Added : added
# Price : price
# Beta : beta
# MVA : mva
# kekayaan : kaya
# dihasilkan : hasil
# penghasilan : hasil
# pemegang : pegang
# pemilik : milik
# PER : per
# prospek : prospek
# tingginya : tinggi
# sensitivitas : sensitivitas
# Expected : expected
# Mita : mita
# Anggun : anggun
# Pratiwi : pratiwi
# Kosmetik : kosmetik
# Wardah : wardah
# Muhamad : muhamad
# Penelitin : penelitin
# ditimbulkan : timbul
# kosmetik : kosmetik
# wardah : wardah
# sosail : sosail
# Mahasiswi : mahasiswi
# Makan : makan
# Lesehan : leseh
# Berkah : berkah
# Ilaahi : ilaahi
# Menganti : anti
# Faiqotul : faiqotul
# Muna : muna
# Corporate : corporate
# Social : social
# Responsibility : responsibility
# Semen : semen
# Sudarsono : sudarsono
# level : level
# significance : significance
# linieritas : linieritas
# CSR : csr
# Milyar : milyar
# Sumirah : sumirah
# Penjualan : jual
# UD : ud
# Budi : budi
# Kramat : kramat
# TambrinMM : tambrinmm
# ChrismardaniSsiMM : chrismardanissimm
# tekhnik : tekhnik
# relase : rase
# kesatuan : satu
# sisa : sisa
# satuan : satu
# menurun : turun
# penjulannya : penjulannya
# independent : independent
# hipotesa : hipotesa
# signifikasi : signifikasi
# teruji : uji
# Miftahul : miftahul
# Rizki : rizki
# Efektivitas : efektivitas
# Efisiensi : efisiensi
# Anggaran : anggar
# Jiwa : jiwa
# Menur : menur
# Makhmud : makhmud
# Zulkifli : zulkifli
# anggaran : anggar
# unit : unit
# penulis : tulis
# beralamat : alamat
# No : no
# Sebagai : bagai
# pertanggungjawaban : pertanggungjawaban
# transaksi : transaksi
# rekening : rekening
# koran : koran
# bentu : bentu
# diberlakukannya : laku
# Peraturan : atur
# Menteri : menteri
# Negeri : negeri
# Nomor : nomor
# pedoman : pedoman
# wajib : wajib
# menyusun : susun
# neraca : neraca
# realisasi : realisasi
# catatan : catat
# Laporan : lapor
# disusun : susun
# keefektifan : efektif
# keefisiensian : efisiensi
# keuangannya : uang
# mengetahuan : tahu
# menunujukkan : menunujukkan
# terbilang : bilang
# prosentase : prosentase
# Kriteria : kriteria
# Setyo : setyo
# Egy : egy
# Afrian : afrian
# Arus : arus
# Likuiditas : likuiditas
# Sektor : sektor
# Rokok : rokok
# DrsEc : drsec
# arus : arus
# Handjaya : handjaya
# Mandala : mandala
# Bentoel : bentoel
# Investama : investama
# diikuti : ikut
# Anugerah : anugerah
# Nanda : nanda
# BojonegoroPutera : bojonegoroputera
# Contractor : contractor
# General : general
# Supplier : supplier
# Bojonegoro : bojonegoro
# balas : balas
# adil : adil
# pekerja : kerja
# jasajasanya : jasajasanya
# memotivasi : motivasi
# merangsang : rangsang
# Putera : putera
# kompesasi : kompesasi
# sebabkan : sebab
# ID : id
# FITRI : fitri
# ANNA : anna
# SARI : sari
# Hotel : hotel
# Madinah : madinah
# Pemekasan : kas
# As : as
# diajukan : aju
# Xe : xe
# konsuman : konsuman
# memprioritaskan : prioritas
# Kara : kara
# Abthal : abthal
# Asyraf : asyraf
# Agatha : agatha
# Adetya : adetya
# Pengguna : guna
# Hicard : hicard
# Hypermart : hypermart
# Plaza : plaza
# bondingikatan : bondingikatan
# empathyempati : empathyempati
# reciprocitytimbal : reciprocitytimbal
# trustkepercayaan : trustkepercayaan
# penelian : tian
# hicard : hicard
# bonding : bonding
# ikatan : ikat
# empathy : empathy
# reciprocity : reciprocity
# trust : trust
# tekstil : tekstil
# garmen : garmen
# bunga : bunga
# lembar : lembar
# pengembalian : kembali
# Moh : moh
# Amiruddin : amiruddin
# Eceran : ecer
# Family : family
# Hendry : hendry
# Maruf : maruf
# Bangakalan : bangakalan
# pemebelianj : pemebelianj
# poduk : poduk
# dilatarbelakangi : dilatarbelakangi
# bertransaksi : transaksi
# Pihak : pihak
# pengusaha : usaha
# strategistrategi : strategistrategi
# memenangkan : menang
# Unsurunsur : unsurunsur
# pengelola : kelola
# tujuannya : tuju
# meningkatkanmemuaskan : meningkatkanmemuaskan
# situs : situs
# wwwrumahmadanicom : wwwrumahmadanicom
# chatting : chatting
# adalahdiskriptif : adalahdiskriptif
# reksadana : reksadana
# syariah : syariah
# diwakili : wakil
# Jakarta : jakarta
# Islamic : islamic
# suku : suku
# Sharpe : sharpe
# TreynordanJensenObjekpenelitianpadapenelitianiniadalah : treynordanjensenobjekpenelitianpadapenelitianiniadalah
# PNM : pnm
# AAAAmanahSyariah : aaaamanahsyariah
# Fund : fund
# danDanareksaSyariahBerimbang : dandanareksasyariahberimbang
# menggunakana : menggunakana
# Treynor : treynor
# jensen : jensen
# ketiga : tiga
# Jensen : jensen
# ukur : ukur
# Danareksa : danareksa
# Berimbang : imbang
# Reksadana : reksadana
# AAA : aaa
# Amanah : amanah
# Pengukuran : ukur
# terendah : rendah
# Mutasi : mutasi
# Jabatan : jabat
# Kepala : kepala
# Sekolah : sekolah
# diartikan : arti
# perpindahan : pindah
# gaji : gaji
# tingkatan : tingkat
# Selain : selain
# mutasi : mutasi
# tandai : tanda
# kepala : kepala
# sekolah : sekolah
# slovin : slovin
# tehnik : tehnik
# gresik : gresik
# Jannah : jannah
# Smartphone : smartphone
# Gemini : gemini
# Curve : curve
# PambudiSE : pambudise
# customer : customer
# kualitaskinerja : kualitaskinerja
# hargavalue : hargavalue
# money : money
# smartphone : smartphone
# November : november
# Nikmatul : nikmatul
# Hoiriyah : hoiriyah
# Pengambilan : ambil
# Baru : baru
# tempatdistribusi : tempatdistribusi
# proportional : proportional
# stratified : stratified
# tabunganku : tabung
# Indli : indli
# Roudlotul : roudlotul
# Vixion : vixion
# pintar : pintar
# pintarpintar : pintarpintar
# Identitas : identitas
# nama : nama
# melekat : lekat
# ...
# angket : angket
# Dividend : dividend
# DPS : dps
# Pemilihan : pilih
# eksternal : eksternal
# persediaan : sedia
# bahan : bahan
# baku : baku
# PROPINDO : propindo
# WIRA : wira
# UTAMA : utama
# proyek : proyek
# perumahan : rumah
# Carson : carson
# Regency : regency
# economic : economic
# order : order
# quantity : quantity
# safety : safety
# reorder : reorder
# EOQ : eoq
# pemesanan : mesan
# pembangunan : bangun
# pasir : pasir
# jawa : jawa
# zak : zak
# semen : semen
# biji : biji
# bata : bata
# putih : putih
# pesanan : pesan
# Rit : rit
# Reorder : reorder
# Point : point
# rit : rit
# pengaman : kam
# Zak : zak
# Pengendalian : kendali
# penghematan : hemat
# Experiential : experiential
# sense : sense
# feel : feel
# think : think
# act : act
# relate : relate
# kepuasaan : puasa
# blackberry : blackberry
# curve : curve
# Yuliana : yuliana
# Pengembalian : kembali
# Optimal : optimal
# Index : index
# JII : jii
# Investasi : investasi
# penanaman : tanam
# dikemudian : kemudi
# Kegiatan : giat
# Penilaian : nilai
# komposisi : komposisi
# diinvestasikan : investasi
# Single : single
# pembentukan : bentuk
# kreteria : kreteria
# Alam : alam
# Sutera : sutera
# Realty : realty
# ASRI : asri
# Unilever : unilever
# UNVR : unvr
# SMGR : smgr
# Lippo : lippo
# Karawaci : karawaci
# LPKR : lpkr
# Kalbe : kalbe
# farma : farma
# KLBF : klbf
# cutoff : cutoff
# Masingmasing : masingmasing
# terbentuk : bentuk
# menjanjikan : janji
# dihadapi : hadap
# Dian : dian
# Ratnasari : ratnasari
# Yahya : yahya
# Economic : economic
# EVA : eva
# Menilai : nilai
# Keuangan : uang
# Aktif : aktif
# LQ : lq
# Bei : bei
# bimbinga : bimbinga
# meyebutkan : meyebutkan
# bernilai : nila
# BCA : bca
# BNI : bni
# Danamon : danamon
# Ratarata : ratarata
# menandakan : tanda
# menghasilka : menghasilka
# RataRata : ratarata
# Tertimbang : timbang
# Miftah : miftah
# Ulfa : ulfa
# kegiatankegiatan : kegiatankegiatan
# berfungsi : fungsi
# kompetitif : kompetitif
# Barang : barang
# konsumennya : konsumen
# pengiriman : kirim
# penerimaan : terima
# surat : surat
# paket : paket
# dibanding : banding
# kompetitorkompetitor : kompetitorkompetitor
# Lailia : lailia
# Ningsih : ningsih
# Penggunaan : guna
# Akuntansi : akuntansi
# Pertanggungjawaban : pertanggungjawaban
# Dasar : dasar
# Ruang : ruang
# Rawat : rawat
# Inap : inap
# Paru : paru
# BP : bp
# Pemerintah : perintah
# Hukum : hukum
# Bentuk : bentuk
# badan : badan
# hukum : hukum
# Pemendagri : pemendagri
# Pergub : pergub
# Jatim : jatim
# Oleh : oleh
# penggunaaan : penggunaaan
# eksistensinya : eksistensi
# pemborosan : boros
# ruang : ruang
# teridentifikasi : identifikasi
# pengawasan : awas
# mengeliminasi : eliminasi
# activity : activity
# Zainab : zainab
# Solvabilitas : solvabilitas
# Transportasi : transportasi
# assets : assets
# turnoverdebt : turnoverdebt
# turnover : turnover
# Andrian : andrian
# Agaf : agaf
# PENGARUH : pengaruh
# EMOTIONAL : emotional
# BRANDING : branding
# LOYALITAS : loyalitas
# PADA : pada
# PRODUK : produk
# GARNIER : garnier
# MEN : men
# Februari : februari
# pilar : pilar
# emotional : emotional
# branding : branding
# panca : panca
# indera : indera
# imajinasi : imajinasi
# Garnier : garnier
# Men : men
# pria : pria
# jurusan : jurus
# angkatan : angkat
# Emotional : emotional
# Branding : branding
# Uswatun : uswatun
# Hasanah : hasanah
# Finansial : finansial
# AnugrahiniIrawatiMM : anugrahiniirawatimm
# padat : padat
# menyita : sita
# koofisien : koofisien
# Mengingat : ingat
# kreativitas : kreativitas
# pelatihanpelatihan : pelatihanpelatihan
# outbond : outbond
# terealisasi : realisasi
# reward : reward
# berdeda : berdeda
# rewardreward : rewardreward
# Permasalahan : masalah
# BAPPEDA : bappeda
# menonjol : tonjol
# kenyamanan : nyaman
# berperilaku : perilaku
# Pembangunan : bangun
# menumbuhkan : tumbuh
# niloai : niloai
# norma : norma
# Bedasarkan : bedasarkan
# menerbitkan : terbit
# mempublikasikan : publikasi
# tahunan : tahun
# delisting : delisting
# publikasi : publikasi
# Indonesian : indonesian
# Directory : directory
# ICMD : icmd
# tstatistik : tstatistik
# fstatistik : fstatistik
# Sementara : sementara
# tehadap : tehadap
# Hana : hana
# Sunarsih : sunarsih
# Fundamental : fundamental
# Makro : makro
# Makanan : makan
# DrsEcMakhmud : drsecmakhmud
# ZulkifliMSi : zulkiflimsi
# SudarsonoMM : sudarsonomm
# yag : yag
# Shareinflasi : shareinflasi
# Tinggi : tinggi
# pengangguran : anggur
# kesiapan : kesiap
# Prodi : prodi
# Gerbang : gerbang
# Kertasusila : kertasusila
# Univesitas : univesitas
# Diduga : duga
# kepercyaan : kepercyaan
# Konsep : konsep
# Kesiapan : kesiap
# criteria : criteria
# Banyaknya : banyak
# merger : merger
# akuisisi : akuisisi
# CR : cr
# TATO : tato
# DER : der
# perbankan : perban
# ditentukan : tentu
# Dewi : dewi
# Pengunjung : unjung
# Museum : museum
# Sepuluh : puluh
# Nopember : nopember
# Mohammad : mohammad
# Arief : arief
# pahlawan : pahlawan
# menyimpan : simpan
# sejarah : sejarah
# perang : perang
# kemerdekaan : merdeka
# objekobjek : objekobjek
# wisata : wisata
# bernuansa : nuansa
# museum : museum
# Melihat : lihat
# mengunjungi : unjung
# menghabiskan : habis
# mall : mall
# bioskop : bioskop
# cafe : cafe
# Sense : sense
# Experience : experience
# Feel : feel
# Think : think
# Act : act
# Relate : relate
# pengunjung : unjung
# Kelima : lima
# Asia : asia
# Tenggara : tenggara
# Kuala : kuala
# Exchange : exchange
# KLSE : klse
# Philippines : philippines
# PSE : pse
# Strait : strait
# Times : times
# STI : sti
# Gabungan : gabung
# IHSG : ihsg
# bergandaPeriode : bergandaperiode
# Oktober : oktober
# Juli : juli
# Lumpur : lumpur
# peneletian : peneletian
# diarahkan : arah
# memanfaatkan : manfaat
# mencerminkan : cermin
# prinsip : prinsip
# pengurus : urus
# Yayasan : yayasan
# Tamirul : tamirul
# Masjid : masjid
# harmonis : harmonis
# penghargaan : harga
# sangsi : sangsi
# Pengurus : urus
# Yusri : yusri
# Evarika : evarika
# NRP : nrp
# Tentang : tentang
# Wisata : wisata
# Pantai : pantai
# Lombang : lombang
# Menarik : tarik
# penyebab : sebab
# berkembangnya : kembang
# pantai : pantai
# merumuskan : rumus
# LombangPenelitian : lombangpenelitian
# SWOT : swot
# IE : ie
# sel : sel
# jaga : jaga
# pertahankan : tahan
# Pangsa : pangsa
# Memperbaiki : baik
# Menetapkan : tetap
# lokal : lokal
# Septy : septy
# Ariyati : ariyati
# Perbankan : perban
# Springate : springate
# Zmijewski : zmijewski
# Pranjoto : pranjoto
# terdafatar : terdafatar
# purposif : purposif
# BTN : btn
# dikategorikan : kategori
# kesulitan : sulit
# BSM : bsm
# pengoptimalisasian : optimalisasi
# organisasional : organisasional
# intern : intern
# manajerial : manajerial
# Pimpinan : pimpin
# puncak : puncak
# menengah : tengah
# moment : moment
# Alpha : alpha
# Cronbach : cronbach
# one : one
# tail : tail
# liner : liner
# Farmasi : farmasi
# Purpossive : purpossive
# Statistical : statistical
# Service : service
# Solution : solution
# duga : duga
# DAR : dar
# Hadiatullah : hadiatullah
# perusahaanperusahaan : perusahaanperusahaan
# diinterpretasikan : interpretasi
# Hanjaya : hanjaya
# Internasional : internasional
# lancar : lancar
# garam : garam
# mandala : mandala
# earned : earned
# inventory : inventory
# fixed : fixed
# Lukman : lukman
# waqi : waqi
# arianto : arianto
# publik : publik
# DRS : drs
# EC : ec
# Mahkmud : mahkmud
# SI : si
# MSI : msi
# mengandung : kandung
# pastian : pasti
# dikehendaki : hendak
# Para : para
# mengkombinasikan : kombinasi
# sekuritas : sekuritas
# tercatat : catat
# standart : standart
# deviasi : deviasi
# kombinasi : kombinasi
# Trada : trada
# Maritime : maritime
# ambil : ambil
# potofolio : potofolio
# pleh : pleh
# diversifikasi : diversifikasi
# Refti : refti
# selvi : selvi
# Wahyuni : wahyuni
# Stres : stres
# Pajak : pajak
# Pratama : pratama
# RM : rm
# Mochammad : mochammad
# Wispandono : wispandono
# SEMS : sems
# KPP : kpp
# Kehidupan : hidup
# Administrasi : administrasi
# institusi : institusi
# penggerak : gerak
# penentu : tentu
# tercapainya : capa
# Peningkatan : tingkat
# inovatif : inovatif
# berpengruh : ruh
# Muazzah : muazzah
# judul : judul
# Overreaction : overreaction
# dosem : dosem
# pembimbing : bimbing
# Msi : msi
# decade : decade
# perdagangkan : dagang
# penyimpangan : simpang
# Januari : januari
# effect : effect
# day : day
# week : week
# Overreactio : overreactio
# lakukan : laku
# mengatahui : mengatahui
# reaksi : reaksi
# peristiwa : peristiwa
# puasa : puasa
# menjelang : jelang
# lebaran : lebaran
# Reaksi : reaksi
# in : in
# abnormal : abnormal
# loser : loser
# winner : winner
# deduktif : deduktif
# faktafakta : faktafakta
# teoriteori : teoriteori
# simpulkan : simpul
# pola : pola
# AAR : aar
# Average : average
# CAR : car
# Cumulative : cumulative
# abnormar : abnormar
# temukan : temu
# menggungguli : menggungguli
# temukannya : temu
# berbalik : balik
# arah : arah
# LUTFI : lutfi
# KAMALI : kamal
# Teh : teh
# Botol : botol
# SOSRO : sosro
# Study : study
# Sp : sp
# teh : teh
# botol : botol
# kontrak : kontrak
# Sapta : sapta
# Pusaka : pusaka
# Nusantara : nusantara
# SPGN : spgn
# Popuasi : popuasi
# dilapangan : lapang
# Linear : linear
# Abd : abd
# Hakam : hakam
# Sunsilk : sunsilk
# Clean : clean
# And : and
# Fresh : fresh
# Shampoo : shampoo
# Santri : santri
# Putri : putri
# Pondok : pondok
# Pesantren : pesantren
# Al : al
# Hikam : hikam
# sunsilk : sunsilk
# clean : clean
# fresh : fresh
# santri : santri
# putri : putri
# pondok : pondok
# pesantren : pesantren
# Ciri : ciri
# Anik : anik
# Arismah : arismah
# Sido : sido
# Tulis : tulis
# Sendang : sendang
# pengaruhcitra : pengaruhcitra
# terhadapkeputusan : terhadapkeputusan
# produku : produku
# Alfian : alfian
# Fachrezi : fachrezi
# Keinginan : ingin
# Pindah : pindah
# Keja : keja
# Toserba : toserba
# Gading : gading
# Kuning : kuning
# Muji : muji
# keterikatan : ikat
# erat : erat
# pindah : pindah
# asumsikan : asumsi
# pemenuhan : penuh
# kebijakankebijakan : kebijakankebijakan
# perasaan : asa
# intentions : intentions
# rekan : rekan
# penelitia : penelitia
# alasan : alas
# fundamental : fundamental
# intention : intention
# Risqiyatul : risqiyatul
# Maqfiroh : maqfiroh
# Sepeda : sepeda
# Mio : mio
# Soul : soul
# Trisakti : trisakti
# seraca : seraca
# Bachrowi : bachrowi
# Yoghurt : yoghurt
# Cimory : cimory
# Cisarua : cisarua
# Mountain : mountain
# Dairy : dairy
# CisaruaBogor : cisaruabogor
# Masayarakat : masayarakat
# SsiMM : ssimm
# yoghurt : yoghurt
# cimory : cimory
# terdiridari : terdiridari
# Yulita : yulita
# SPMSi : spmsi
# Indra : indra
# Ketegasan : tegas
# Pemimpin : pimpin
# Apollo : apollo
# WildanSEMsi : wildansemsi
# ketegasan : tegas
# pemimpin : pimpin
# GALIH : galih
# PRASETYO : prasetyo
# Helm : helm
# BMC : bmc
# pembuat : buat
# pemakai : pakai
# Nasirudin : nasirudin
# Gaya : gaya
# Pegantenan : pegantenan
# SSTSEMMT : sstsemmt
# otoriter : otoriter
# demokratis : demokratis
# pegantenan : pegantenan
# Xmenpunyai : xmenpunyai
# negative : negative
# Xmempunyai : xmempunyai
# Esteem : esteem
# berdagangan : dagang
# Fortune : fortune
# FMS : fms
# esteem : esteem
# peneliian : peneliian
# statistika : statistika
# menemukan : temu
# Lalu : lalu
# Rahayu : rahayu
# Purwati : purwati
# Akuisisi : akuisisi
# Melakukan : laku
# Mkes : mkes
# ROEReturn : roereturn
# CRCurrent : crcurrent
# Assets : assets
# Siti : siti
# Mariyam : mariyam
# Financial : financial
# Leverage : leverage
# DrsEcBambang : drsecbambang
# Prasteyo : prasteyo
# financial : financial
# klasi : klasi
# quick : quick
# Haryati : haryati
# Akuisitor : akuisitor
# Pengaruhnya : pengaruh
# akuisitor : akuisitor
# longterm : longterm
# Ttest : ttest
# determinansi : determinansi
# pengaruhi : pengaruh
# Keyword : keyword
# Adequacy : adequacy
# Operational : operational
# Efficiency : efficiency
# Deposit : deposit
# terkinik : terkinik
# capital : capital
# adequacy : adequacy
# operational : operational
# efficiency : efficiency
# loan : loan
# deposit : deposit
# FARID : farid
# MOTIVASI : motivasi
# KERJA : kerja
# KINERJA : kerja
# KARYAWAN : karyawan
# DI : di
# PUSKESMAS : puskesmas
# TANAH : tanah
# MERAH : merah
# KABUPATEN : kabupaten
# DIBAWAH : bawah
# BIMBINGAN : bimbing
# MUDJI : mudji
# KUSWINARNO : kuswinarno
# HELMI : helm
# BUYUNG : buyung
# AULIA : aulia
# ST : st
# MMT : mmt
# YANG : yang
# TERDIRI : diri
# DARI : dari
# KEBUTUHAN : butuh
# KESELAMATAN : selamat
# KEAMANAN : aman
# SOSIAL : sosial
# AKAN : akan
# PENGHARGAAN : harga
# AKTUALISASI : aktualisasi
# DIRI : diri
# MERUPAKAN : rupa
# SALAH : salah
# SATU : satu
# FAKTOR : faktor
# PENTING : penting
# DAPAT : dapat
# MEMPENGARUHI : pengaruh
# DALAM : dalam
# PENCAPAIAN : capai
# BAIK : baik
# SANGAT : sangat
# UNTUK : untuk
# MEMPERHATIKAN : perhati
# MANAJEMEN : manajemen
# PENGELOLAAN : kelola
# TINGKAT : tingkat
# KEBUTUHANKEBUTUHAN : kebutuhankebutuhan
# SEPERTI : seperti
# PEMBINAAN : bina
# DIBERIKAN : beri
# DIPERHATIKAN : perhati
# MENGACU : acu
# KEPADA : kepada
# AGAR : agar
# SEMANGAT : semangat
# FOKUS : fokus
# BEKERJA : kerja
# PENELITIAN : teliti
# INI : ini
# BERTUJUAN : tuju
# MENGETAHUI : tahu
# KEMUDIAN : kemudian
# VARIABEL : variabel
# BEBAS : bebas
# BERPENGARUH : pengaruh
# SECARA : cara
# SIMULTAN : simultan
# DOMINAN : dominan
# BERDASARKAN : dasar
# HASIL : hasil
# ANALISIS : analisis
# REGRESI : regresi
# LINIER : linier
# BERGANDA : ganda
# MAKA : maka
# DIDAPATKAN : dapat
# FISIOLOGIS : fisiologis
# SEBESAR : besar
# KOEFISIEN : koefisien
# DETERMINASI : determinasi
# ATAU : atau
# SQUARE : square
# MENUNJUKKAN : tunjuk
# HAL : hal
# BAHWA : bahwa
# PERSENTASE : persentase
# SOCIAL : social
# ADALAH : adalah
# SEDANGKAN : sedang
# SISANYA : sisa
# DIPENGARUHI : pengaruh
# DIJELASKAN : jelas
# OLEH : oleh
# LAIN : lain
# TIDAK : tidak
# DIMASUKKAN : masuk
# HIPOTESIS : hipotesis
# KEDUA : dua
# DISIMPULKAN : simpul
# PARSIAL : parsial
# PRUDUKTIFITAS : pruduktifitas
# PENGRAJIN : rajin
# BATIK : batik
# TANJUNG : tanjung
# BUMI : bumi
# Atika : atika
# Citrawaty : citrawaty
# Intelektual : intelektual
# IQ : iq
# EQ : eq
# Spiritual : spiritual
# SQ : sq
# Tenaga : tenaga
# Transmigrasi : transmigrasi
# disebuah : buah
# Pemerintahan : perintah
# diklasifikasikan : klasifikasi
# intelektual : intelektual
# spiritual : spiritual
# individual : individual
# Maulina : maulina
# Hotim : hotim
# Kepribadian : pribadi
# Kehutanan : hutan
# Perkebunan : kebun
# MS : ms
# absensi : absensi
# utamanya : utama
# aparatur : aparatur
# pelaksanaanya : pelaksanaanya
# megetahui : megetahui
# Kab : kab
# BangkalanUntuk : bangkalanuntuk
# BangkalaSerta : bangkalaserta
# sebarkan : sebar
# subjek : subjek
# kehutanan : hutan
# perkenunan : nun
# kuci : kuci
# Lely : lely
# Nurvillah : nurvillah
# Anggraini : anggraini
# Hidup : hidup
# Kedisiplinan : disiplin
# hidup : hidup
# kedisiplinan : disiplin
# menjadikan : jadi
# Alisyahbana : alisyahbana
# Kreativitas : kreativitas
# Kerjasama : kerjasama
# Tim : tim
# Pendamping : damping
# Unit : unit
# Pelaksana : laksana
# Keluarga : keluarga
# Harapan : harap
# Wisapandono : wisapandono
# kerjasama : kerjasama
# tim : tim
# pendamping : damping
# ketidaktepatan : ketidaktepatan
# UPPKH : uppkh
# Sabun : sabun
# Lux : lux
# kausal : kausal
# nonprobability : nonprobability
# insidental : insidental
# Pengolahanya : pengolahanya
# grafis : grafis
# warna : warna
# sabun : sabun
# Agus : agus
# Supriadi : supriadi
# Store : store
# Atmosphere : atmosphere
# Bakmi : bakmi
# Gili : gili
# tidaknya : tidak
# Exterior : exterior
# Interior : interior
# Layout : layout
# Display : display
# bakmi : bakmi
# gili : gili
# incidental : incidental
# anaisis : anaisis
# penilitian : penilitian
# store : store
# atmosphere : atmosphere
# general : general
# exterior : exterior
# interior : interior
# layout : layout
# sgnifikan : sgnifikan
# bersamaan : sama
# analis : analis
# tdak : tdak
# Lailatul : lailatul
# Qodriyah : qodriyah
# NIM : nim
# pukesmas : pukesmas
# tanah : tanah
# merah : merah
# IsmailDraMM : ismaildramm
# divisi : divisi
# good : good
# PUKESMAS : pukesmas
# bangkalani : bangkalani
# dihitung : hitung
# arti : arti
# Konstanta : konstanta
# Jika : jika
# Sikap : sikap
# Menyatakan : nyata
# ikuti : ikut
# sikapi : sikap
# tentukan : tentu
# Kuncisikapmotivasikinerja : kuncisikapmotivasikinerja
# Mempengaruhi : pengaruh
# Organisasional : organisasional
# Dok : dok
# Perkapalan : kapal
# dikenal : kenal
# Luqmanul : luqmanul
# Hakim : hakim
# Assohidi : assohidi
# Seleksi : seleksi
# keterkaitan : kait
# berkualitas : kualitas
# Software : software
# Package : package
# Science : science
# Slovin : slovin
# temuan : temu
# direkomendasikan : rekomendasi
# Imroatus : imroatus
# soleha : soleha
# PU : pu
# Bina : bina
# Pengairan : air
# SafrizalST : safrizalst
# SEMMT : semmt
# pemerintah : perintah
# terintegrasi : integrasi
# peranannya : peran
# termotivasi : motivasi
# ditunjukan : tunjuk
# adala : adala
# Observasi : observasi
# teradap : adap
# posotif : posotif
# Hudan : hudan
# Dardiri : dardiri
# Septiawan : septiawan
# Casablanca : casablanca
# Pomade : pomade
# Kasus : kasus
# Rambut : rambut
# Pomede : pomede
# Distibusi : distibusi
# Partisipasi : partisipasi
# sekedar : dar
# menjadiibu : menjadiibu
# wanitayang : wanitayang
# perekonomian : ekonomi
# karenaingin : karenaingin
# mengasah : asah
# milikidalam : milikidalam
# terkecuali : kecuali
# karyawati : karyawati
# karyawatinya : karyawatinya
# menikah : meni
# disadari : sadar
# atautidak : atautidak
# dalamkeluarga : dalamkeluarga
# dilingkungan : lingkung

# %%
df

# %% [markdown]
# # Clustering

# %%
vectorizer = TfidfVectorizer(stop_words='english')
berita = []
for data in data_berita['Abstraksi']:
    isi = ''
    for term in data:
        isi += term + ' '
    berita.append(isi)

vectorizer.fit(data_berita)
X = vectorizer.fit_transform(data_berita)

true_k = 5
model = KMeans(n_clusters=true_k, init='k-means++', max_iter=100, n_init=1)
model.fit(X)

print("Top terms per cluster:")
order_centroids = model.cluster_centers_.argsort()[:, ::-1]
terms = vectorizer.get_feature_names()
for i in range(true_k):
    print("Cluster %d:" % i),
    for ind in order_centroids[i, :10]:
        print(' %s' % terms[ind]),
    print
